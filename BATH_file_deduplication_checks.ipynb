# %% [markdown]
# <a href="https://colab.research.google.com/github/NehaSontakk/BATH-Prokka-Comparison/blob/main/BATH_file_deduplication_checks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
e_value_threshold = 0.000001

# %%
class filtering_operations:

  @staticmethod
  def e_value_filtering(df):
    return df.loc[df['E-value']<=e_value_threshold]

  @staticmethod
  def pos_neg_strand_filtering(df_filtered):
    #df should be post e_value_filteration
    df = filtering_operations.e_value_filtering(df_filtered)
    #Strand identification
    df['ali from'] = df['ali from'].astype(int)
    df['ali to'] = df['ali to'].astype(int)
    strand = []

    for index,row in df.iterrows():
      if row['ali from'] < row['ali to']:
        strand.append("+")
      elif row['ali from'] > row['ali to']:
        strand.append("-")

    df['strand'] = strand
    return df

  @staticmethod
  def get_specific_strand(df_raw,strand_info):
    df = filtering_operations.pos_neg_strand_filtering(df_raw)
    return df.loc[df['strand']==strand_info]

# %%
class overlap_deduplications:

  ali_to_column = ""
  ali_from_column = ""

  #METHODS FOR 100% DEDUPLICATION

  @staticmethod
  def handle_group(group):
    #Now for each element in group
    min_e_value = group['E-value'].min()
    #find elements with lowest e-values
    group_min_e = group.loc[group['E-value'] == min_e_value]
    #if group contains a single row save it
    if len(group_min_e) == 1:
      return group_min_e
    #if group contains multiple rows with same e-values check min score
    elif len(group_min_e) > 1:
      return group_min_e.iloc[0:1]

  @staticmethod
  def deduplicate_full_overlaps(df):
    #100% Overlap Dedup
    print("Number of elements in relevant strand: ",df.shape)
    #Find all the duplicates
    duplicates = df.duplicated(subset=['target name',overlap_deduplications.ali_from_column, overlap_deduplications.ali_to_column], keep=False)
    #make a duplicates df
    duplicates_df = df[duplicates]
    #make a non duplicates df
    not_duplicate_df = df[~duplicates]
    print("Number of exact duplicates or homologs: ",duplicates_df.shape)
    #Sort by E-value and score
    duplicates_df1 = duplicates_df.sort_values(by=['E-value', 'score'], ascending=[True, False])
    deduplicated_remhomologs = duplicates_df1.groupby(['target name',overlap_deduplications.ali_from_column,overlap_deduplications.ali_to_column], group_keys=False).apply(overlap_deduplications.handle_group).reset_index(drop=True)
    #rejion after deduplication
    dedup_step1 = pd.concat([not_duplicate_df,deduplicated_remhomologs]).sort_values(['target name','ali from','E-value'])
    print("Number of elements after removing exact duplicates or homologs: ",dedup_step1.shape)
    print("Elements removed: ",df.shape[0] - dedup_step1.shape[0])
    return dedup_step1

  #METHODS FOR 70% DEDUPLICATION

  @staticmethod
  def calculate_overlap(hit_a, hit_b):
    #print("Overlap calculations done on columns:",overlap_deduplications.ali_from_column,overlap_deduplications.ali_to_column)
    start_a, end_a = hit_a[overlap_deduplications.ali_from_column], hit_a[overlap_deduplications.ali_to_column]
    start_b, end_b = hit_b[overlap_deduplications.ali_from_column], hit_b[overlap_deduplications.ali_to_column]

    overlap_length = max(0, min(end_a, end_b) - max(start_a, start_b) + 1)
    #print(min(end_a, end_b))
    #print(max(start_a, start_b))
    #print("Overlap length",overlap_length)

    length_a = end_a - start_a + 1
    length_b = end_b - start_b + 1

    #print("Length",length_a,length_b)
    if length_a > 0 and length_b > 0:
        overlap_perc_a = (overlap_length / length_a) * 100
        overlap_perc_b = (overlap_length / length_b) * 100
        return overlap_perc_a, overlap_perc_b
    else:
        return 0, 0

  @staticmethod
  def calculate_winner(hit_a, hit_b):
      overlap1, overlap2 = overlap_deduplications.calculate_overlap(hit_a, hit_b)
      print(f"Comparing:\nHit A: {hit_a}\nHit B: {hit_b}\nOverlap1: {overlap1}%, Overlap2: {overlap2}%")

      # Check for significant overlap
      if overlap1 >= 70 or overlap2 >= 70:
          # Determine which hit to retain based on E-value or sequence length on tie
          if hit_a['E-value'] < hit_b['E-value']:
              print("Choosing Hit A based on E-value")
              return hit_a
          elif hit_a['E-value'] > hit_b['E-value']:
              print("Choosing Hit B based on E-value")
              return hit_b
          else:  # E-values are tied, check the sequence length
              if hit_a['seq len'] > hit_b['seq len']:
                  print("E-values tied. Choosing Hit A based on larger sequence length")
                  return hit_a
              else:
                  print("E-values tied. Choosing Hit B based on larger sequence length")
                  return hit_b
      else:
          print("No significant overlap or both hits retained")
          return hit_a, hit_b

  @staticmethod
  def handle_70_overlaps(group):
    items = []
    for index, row in group.iterrows():
      row_tuple = row.to_dict()
      items.append(row_tuple)

    i = 0
    all_winners = []

    while i<len(items)-1:
      current = items[i]
      next_item = items[i+1]
      print("Begining Comparison: ",i)
      #print(current,"\n",next_item)
      result = overlap_deduplications.calculate_winner(current, next_item)

      #If result is two items append the current item to winners list since overlap of current item with next item is less than 70% so we want to keep both
      if isinstance(result,tuple):
        if result[0] not in all_winners:
          all_winners.append(result[0])
          #print("Tuple returned!")
          #print("Appending: ",result[0])
          #print("All winners currently: ",all_winners)
        #else:
        #  print("Result already in all winners, no appending!")
        i += 1
      else:
        if result == current:
          #print("Result is ",i," element and not ",i+1," popping: ",items[i+1])
          items.pop(i+1)
        else:
          i += 1

      if i >= len(items) - 1 and items[-1] not in all_winners:
        all_winners.append(items[-1])

    return pd.DataFrame(all_winners)

  #METHODS FOR LESS THAN 70% DEDUPLICATION
  @staticmethod
  def calculate_below_70_changes(hit_a, hit_b):
    overlap1, overlap2 = overlap_deduplications.calculate_overlap(hit_a, hit_b)
    #print("Overlap 1: ",overlap1)
    if (0.01 <= overlap1 < 70) and (0.01 <= overlap2 < 70):
      if hit_a['E-value'] < hit_b['E-value']:
        #print("Case A: A dominates")
        #print(hit_a)
        #print(hit_b)
        hit_b['ali from'] = hit_a['ali to'] + 1
        #print(hit_b)
        return hit_a, hit_b
      else:
        #print("Case B: B dominates")
        #print(hit_a)
        #print(hit_b)
        hit_a['ali to'] = hit_b['ali from'] - 1
        #print(hit_a)
        #print(hit_b)
        return hit_a, hit_b
    else:
      return hit_a,hit_b

  @staticmethod
  def below_70_overlap(group):
    items = []
    for index, row in group.iterrows():
      row_tuple = row.to_dict()
      items.append(row_tuple)

    for i in range(0,len(items)-1):
      element1, element2 = overlap_deduplications.calculate_below_70_changes(items[i],items[i+1])
      items[i] = element1
      items[i+1] = element2

    return pd.DataFrame(items)

  # FINAL METHOD TO CALL
  @staticmethod
  def choose_strand_operations(df):
    if df['strand'].values[0] == '-':
      print("Processing negative strand data...")
      #create the flip columns
      df['ali from flip'] = df['ali to']
      df['ali to flip'] = df['ali from']
      overlap_deduplications.ali_to_column = 'ali to flip'
      overlap_deduplications.ali_from_column = 'ali from flip'
      #100% dedup
      df = df.sort_values(by=['ali from flip','E-value'], ascending=[True, True])
      print(df)
      step1_dedup = overlap_deduplications.deduplicate_full_overlaps(df)
      print("Overlap calculations done on columns:",overlap_deduplications.ali_from_column,overlap_deduplications.ali_to_column)
      print("100% deduplication done.")
      #70% Overlap
      step2_dedup = step1_dedup.groupby(['target name'], group_keys=False).apply(overlap_deduplications.handle_70_overlaps).reset_index(drop=True)
      print("Overlap calculations done on columns:",overlap_deduplications.ali_from_column,overlap_deduplications.ali_to_column)
      print("70% deduplication done.")
      #Less than 70% overlap
      step3_dedup = step2_dedup.groupby(['target name'], group_keys=False).apply(overlap_deduplications.below_70_overlap).reset_index(drop=True)
      print("Less than 70% deduplication done.")
      #return something final
      return step3_dedup
    elif df['strand'].values[0] == '+':
      print("Processing positive strand data...")
      overlap_deduplications.ali_to_column = 'ali to'
      overlap_deduplications.ali_from_column = 'ali from'
      #100% dedup
      df = df.sort_values(by=['ali from','E-value'], ascending=[True, True])
      print(df)
      step1_dedup = overlap_deduplications.deduplicate_full_overlaps(df)
      print("Overlap calculations done on columns:",overlap_deduplications.ali_from_column,overlap_deduplications.ali_to_column)
      print("100% deduplication done.")
      #70% Overlap
      step2_dedup = step1_dedup.groupby(['target name'], group_keys=False).apply(overlap_deduplications.handle_70_overlaps).reset_index(drop=True)
      print("Overlap calculations done on columns:",overlap_deduplications.ali_from_column,overlap_deduplications.ali_to_column)
      print("70% deduplication done.")
      #Less than 70% overlap
      step3_dedup = step2_dedup.groupby(['target name'], group_keys=False).apply(overlap_deduplications.below_70_overlap).reset_index(drop=True)
      print("Less than 70% deduplication done.")
      #return something final
      return step3_dedup

# %%
#Do it for all BATH files we have
from glob import glob

for i in glob("/content/drive/MyDrive/Lab Work/Parkinsons_Data/Bath_Output/*.tbl"):
  bathout = pd.read_table("/content/drive/MyDrive/Lab Work/Parkinsons_Data/Bath_Output/DNA_Bacteria_kingdom_sprot.tbl",sep="\s+",header=None,skiprows=2,skipfooter=8)
  col_names = ['target name', 'accession', 'query name', 'accession1', 'hmm len', 'hmm from', 'hmm to', 'seq len', 'ali from', 'ali to', 'env from', 'env to', 'E-value', 'score', 'bias', 'shifts', 'stops', 'pipe', 'description of target', 'extra']
  bathout.rename(columns=dict(zip(bathout.columns, col_names)), inplace=True)
  df_neg = filtering_operations.get_specific_strand(bathout,"-")
  neg_deduped = overlap_deduplications.choose_strand_operations(df_neg)
  df_pos = filtering_operations.get_specific_strand(bathout,"+")
  pos_deduped = overlap_deduplications.choose_strand_operations(df_pos)
  bath_file_deduplication = pd.concat([pos_deduped,neg_deduped])
  bath_file_deduplication['origin'] = str(i.split("/")[-1].split(".tbl")[0])
  bath_file_deduplication.to_excel(str(i.split("/")[-1].split(".tbl")[0]+".xlsx"),index=False)
# Out:
# <ipython-input-5-718c2c694ba7>:5: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   bathout = pd.read_table("/content/drive/MyDrive/Lab Work/Parkinsons_Data/Bath_Output/DNA_Bacteria_kingdom_sprot.tbl",sep="\s+",header=None,skiprows=2,skipfooter=8)
# <ipython-input-3-830c4c50e74a>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ali from'] = df['ali from'].astype(int)
# <ipython-input-3-830c4c50e74a>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ali to'] = df['ali to'].astype(int)
# <ipython-input-3-830c4c50e74a>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['strand'] = strand
# <ipython-input-4-c8fba195323e>:173: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ali from flip'] = df['ali to']
# <ipython-input-4-c8fba195323e>:174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ali to flip'] = df['ali from']
# Streaming output truncated to the last 5000 lines.
# Comparing:
# Hit A: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P9WG39', 'accession1': '-', 'hmm len': 547, 'hmm from': 15, 'hmm to': 532, 'seq len': 125518, 'ali from': 92966, 'ali to': 91374, 'env from': 92999, 'env to': 91347, 'E-value': 2.6000000000000002e-37, 'score': 140.7, 'bias': 0.2, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 91374, 'ali to flip': 92966}
# Hit B: {'target name': 'k127_748425', 'accession': '-', 'query name': 'Q9LCV9', 'accession1': '-', 'hmm len': 573, 'hmm from': 13, 'hmm to': 260, 'seq len': 125518, 'ali from': 92975, 'ali to': 92235, 'env from': 93002, 'env to': 92211, 'E-value': 2.8e-09, 'score': 46.1, 'bias': 0.1, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 92235, 'ali to flip': 92975}
# Overlap1: 45.951035781544256%, Overlap2: 98.78542510121457%
# Choosing Hit A based on E-value
# Begining Comparison:  61
# Comparing:
# Hit A: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P9WG39', 'accession1': '-', 'hmm len': 547, 'hmm from': 15, 'hmm to': 532, 'seq len': 125518, 'ali from': 92966, 'ali to': 91374, 'env from': 92999, 'env to': 91347, 'E-value': 2.6000000000000002e-37, 'score': 140.7, 'bias': 0.2, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 91374, 'ali to flip': 92966}
# Hit B: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P0AFI0', 'accession1': '-', 'hmm len': 564, 'hmm from': 8, 'hmm to': 559, 'seq len': 125518, 'ali from': 92978, 'ali to': 91317, 'env from': 92990, 'env to': 91305, 'E-value': 1.8e-149, 'score': 511.1, 'bias': 0.2, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 91317, 'ali to flip': 92978}
# Overlap1: 100.0%, Overlap2: 95.84837545126354%
# Choosing Hit B based on E-value
# Begining Comparison:  62
# Comparing:
# Hit A: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P0AFI0', 'accession1': '-', 'hmm len': 564, 'hmm from': 8, 'hmm to': 559, 'seq len': 125518, 'ali from': 92978, 'ali to': 91317, 'env from': 92990, 'env to': 91305, 'E-value': 1.8e-149, 'score': 511.1, 'bias': 0.2, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 91317, 'ali to flip': 92978}
# Hit B: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P40149', 'accession1': '-', 'hmm len': 568, 'hmm from': 9, 'hmm to': 561, 'seq len': 125518, 'ali from': 92981, 'ali to': 91320, 'env from': 92993, 'env to': 91308, 'E-value': 1.2999999999999999e-148, 'score': 508.4, 'bias': 1.5, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 91320, 'ali to flip': 92981}
# Overlap1: 99.81949458483754%, Overlap2: 99.81949458483754%
# Choosing Hit A based on E-value
# Begining Comparison:  62
# Comparing:
# Hit A: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P0AFI0', 'accession1': '-', 'hmm len': 564, 'hmm from': 8, 'hmm to': 559, 'seq len': 125518, 'ali from': 92978, 'ali to': 91317, 'env from': 92990, 'env to': 91305, 'E-value': 1.8e-149, 'score': 511.1, 'bias': 0.2, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 91317, 'ali to flip': 92978}
# Hit B: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P08142', 'accession1': '-', 'hmm len': 562, 'hmm from': 12, 'hmm to': 543, 'seq len': 125518, 'ali from': 92981, 'ali to': 91359, 'env from': 92999, 'env to': 91344, 'E-value': 3.2000000000000003e-23, 'score': 93.5, 'bias': 0.5, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 91359, 'ali to flip': 92981}
# Overlap1: 97.47292418772562%, Overlap2: 99.81515711645102%
# Choosing Hit A based on E-value
# Begining Comparison:  62
# Comparing:
# Hit A: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P0AFI0', 'accession1': '-', 'hmm len': 564, 'hmm from': 8, 'hmm to': 559, 'seq len': 125518, 'ali from': 92978, 'ali to': 91317, 'env from': 92990, 'env to': 91305, 'E-value': 1.8e-149, 'score': 511.1, 'bias': 0.2, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 91317, 'ali to flip': 92978}
# Hit B: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P37251', 'accession1': '-', 'hmm len': 574, 'hmm from': 16, 'hmm to': 372, 'seq len': 125518, 'ali from': 92984, 'ali to': 91917, 'env from': 93014, 'env to': 91863, 'E-value': 2.7e-20, 'score': 84.0, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 91917, 'ali to flip': 92984}
# Overlap1: 63.898916967509024%, Overlap2: 99.43820224719101%
# Choosing Hit A based on E-value
# Begining Comparison:  62
# Comparing:
# Hit A: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P0AFI0', 'accession1': '-', 'hmm len': 564, 'hmm from': 8, 'hmm to': 559, 'seq len': 125518, 'ali from': 92978, 'ali to': 91317, 'env from': 92990, 'env to': 91305, 'E-value': 1.8e-149, 'score': 511.1, 'bias': 0.2, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 91317, 'ali to flip': 92978}
# Hit B: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P00893', 'accession1': '-', 'hmm len': 574, 'hmm from': 2, 'hmm to': 332, 'seq len': 125518, 'ali from': 92984, 'ali to': 92010, 'env from': 92987, 'env to': 91947, 'E-value': 2e-17, 'score': 74.6, 'bias': 0.2, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 92010, 'ali to flip': 92984}
# Overlap1: 58.30324909747292%, Overlap2: 99.38461538461539%
# Choosing Hit A based on E-value
# Begining Comparison:  62
# Comparing:
# Hit A: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P0AFI0', 'accession1': '-', 'hmm len': 564, 'hmm from': 8, 'hmm to': 559, 'seq len': 125518, 'ali from': 92978, 'ali to': 91317, 'env from': 92990, 'env to': 91305, 'E-value': 1.8e-149, 'score': 511.1, 'bias': 0.2, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 91317, 'ali to flip': 92978}
# Hit B: {'target name': 'k127_748425', 'accession': '-', 'query name': 'A3SR25', 'accession1': '-', 'hmm len': 603, 'hmm from': 12, 'hmm to': 363, 'seq len': 125518, 'ali from': 92987, 'ali to': 91935, 'env from': 93008, 'env to': 91851, 'E-value': 5.1e-08, 'score': 44.7, 'bias': 0.5, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 91935, 'ali to flip': 92987}
# Overlap1: 62.8158844765343%, Overlap2: 99.14529914529915%
# Choosing Hit A based on E-value
# Begining Comparison:  62
# Comparing:
# Hit A: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P0AFI0', 'accession1': '-', 'hmm len': 564, 'hmm from': 8, 'hmm to': 559, 'seq len': 125518, 'ali from': 92978, 'ali to': 91317, 'env from': 92990, 'env to': 91305, 'E-value': 1.8e-149, 'score': 511.1, 'bias': 0.2, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 91317, 'ali to flip': 92978}
# Hit B: {'target name': 'k127_748425', 'accession': '-', 'query name': 'Q9HUI8', 'accession1': '-', 'hmm len': 559, 'hmm from': 23, 'hmm to': 383, 'seq len': 125518, 'ali from': 92996, 'ali to': 91913, 'env from': 93054, 'env to': 91854, 'E-value': 6.3e-16, 'score': 70.5, 'bias': 0.0, 'shifts': 6, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 91913, 'ali to flip': 92996}
# Overlap1: 64.13959085439231%, Overlap2: 98.33948339483395%
# Choosing Hit A based on E-value
# Begining Comparison:  62
# Comparing:
# Hit A: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P0AFI0', 'accession1': '-', 'hmm len': 564, 'hmm from': 8, 'hmm to': 559, 'seq len': 125518, 'ali from': 92978, 'ali to': 91317, 'env from': 92990, 'env to': 91305, 'E-value': 1.8e-149, 'score': 511.1, 'bias': 0.2, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 91317, 'ali to flip': 92978}
# Hit B: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P9WG41', 'accession1': '-', 'hmm len': 618, 'hmm from': 25, 'hmm to': 493, 'seq len': 125518, 'ali from': 93017, 'ali to': 91614, 'env from': 93068, 'env to': 91593, 'E-value': 1.4999999999999998e-29, 'score': 114.3, 'bias': 0.3, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 91614, 'ali to flip': 93017}
# Overlap1: 82.12996389891697%, Overlap2: 97.22222222222221%
# Choosing Hit A based on E-value
# Begining Comparison:  62
# Comparing:
# Hit A: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P0AFI0', 'accession1': '-', 'hmm len': 564, 'hmm from': 8, 'hmm to': 559, 'seq len': 125518, 'ali from': 92978, 'ali to': 91317, 'env from': 92990, 'env to': 91305, 'E-value': 1.8e-149, 'score': 511.1, 'bias': 0.2, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 91317, 'ali to flip': 92978}
# Hit B: {'target name': 'k127_748425', 'accession': '-', 'query name': 'Q9KJF0', 'accession1': '-', 'hmm len': 410, 'hmm from': 8, 'hmm to': 198, 'seq len': 125518, 'ali from': 94494, 'ali to': 93919, 'env from': 94509, 'env to': 93886, 'E-value': 9.8e-14, 'score': 60.4, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 93919, 'ali to flip': 94494}
# Overlap1: 0.0%, Overlap2: 0.0%
# No significant overlap or both hits retained
# Begining Comparison:  63
# Comparing:
# Hit A: {'target name': 'k127_748425', 'accession': '-', 'query name': 'Q9KJF0', 'accession1': '-', 'hmm len': 410, 'hmm from': 8, 'hmm to': 198, 'seq len': 125518, 'ali from': 94494, 'ali to': 93919, 'env from': 94509, 'env to': 93886, 'E-value': 9.8e-14, 'score': 60.4, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 93919, 'ali to flip': 94494}
# Hit B: {'target name': 'k127_748425', 'accession': '-', 'query name': 'Q9KJE9', 'accession1': '-', 'hmm len': 409, 'hmm from': 8, 'hmm to': 210, 'seq len': 125518, 'ali from': 94506, 'ali to': 93907, 'env from': 94527, 'env to': 93874, 'E-value': 1.1e-23, 'score': 93.3, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 93907, 'ali to flip': 94506}
# Overlap1: 100.0%, Overlap2: 96.0%
# Choosing Hit B based on E-value
# Begining Comparison:  64
# Comparing:
# Hit A: {'target name': 'k127_748425', 'accession': '-', 'query name': 'Q9KJE9', 'accession1': '-', 'hmm len': 409, 'hmm from': 8, 'hmm to': 210, 'seq len': 125518, 'ali from': 94506, 'ali to': 93907, 'env from': 94527, 'env to': 93874, 'E-value': 1.1e-23, 'score': 93.3, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 93907, 'ali to flip': 94506}
# Hit B: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P19413', 'accession1': '-', 'hmm len': 426, 'hmm from': 12, 'hmm to': 396, 'seq len': 125518, 'ali from': 94506, 'ali to': 93262, 'env from': 94524, 'env to': 93241, 'E-value': 5.7e-11, 'score': 51.6, 'bias': 0.5, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 93262, 'ali to flip': 94506}
# Overlap1: 100.0%, Overlap2: 48.19277108433735%
# Choosing Hit A based on E-value
# Begining Comparison:  64
# Comparing:
# Hit A: {'target name': 'k127_748425', 'accession': '-', 'query name': 'Q9KJE9', 'accession1': '-', 'hmm len': 409, 'hmm from': 8, 'hmm to': 210, 'seq len': 125518, 'ali from': 94506, 'ali to': 93907, 'env from': 94527, 'env to': 93874, 'E-value': 1.1e-23, 'score': 93.3, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 93907, 'ali to flip': 94506}
# Hit B: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P69902', 'accession1': '-', 'hmm len': 416, 'hmm from': 3, 'hmm to': 413, 'seq len': 125518, 'ali from': 94509, 'ali to': 93259, 'env from': 94518, 'env to': 93250, 'E-value': 1.2e-140, 'score': 480.4, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 93259, 'ali to flip': 94509}
# Overlap1: 100.0%, Overlap2: 47.961630695443645%
# Choosing Hit B based on E-value
# Begining Comparison:  65
# Comparing:
# Hit A: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P69902', 'accession1': '-', 'hmm len': 416, 'hmm from': 3, 'hmm to': 413, 'seq len': 125518, 'ali from': 94509, 'ali to': 93259, 'env from': 94518, 'env to': 93250, 'E-value': 1.2e-140, 'score': 480.4, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 93259, 'ali to flip': 94509}
# Hit B: {'target name': 'k127_748425', 'accession': '-', 'query name': 'A9X6P9', 'accession1': '-', 'hmm len': 389, 'hmm from': 11, 'hmm to': 213, 'seq len': 125518, 'ali from': 94509, 'ali to': 93892, 'env from': 94521, 'env to': 93874, 'E-value': 5.8e-37, 'score': 135.1, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 93892, 'ali to flip': 94509}
# Overlap1: 49.40047961630695%, Overlap2: 100.0%
# Choosing Hit A based on E-value
# Begining Comparison:  65
# Comparing:
# Hit A: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P69902', 'accession1': '-', 'hmm len': 416, 'hmm from': 3, 'hmm to': 413, 'seq len': 125518, 'ali from': 94509, 'ali to': 93259, 'env from': 94518, 'env to': 93250, 'E-value': 1.2e-140, 'score': 480.4, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 93259, 'ali to flip': 94509}
# Hit B: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P95149', 'accession1': '-', 'hmm len': 802, 'hmm from': 397, 'hmm to': 605, 'seq len': 125518, 'ali from': 94509, 'ali to': 93889, 'env from': 94521, 'env to': 93865, 'E-value': 8.1e-19, 'score': 79.7, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 93889, 'ali to flip': 94509}
# Overlap1: 49.64028776978417%, Overlap2: 100.0%
# Choosing Hit A based on E-value
# Begining Comparison:  65
# Comparing:
# Hit A: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P69902', 'accession1': '-', 'hmm len': 416, 'hmm from': 3, 'hmm to': 413, 'seq len': 125518, 'ali from': 94509, 'ali to': 93259, 'env from': 94518, 'env to': 93250, 'E-value': 1.2e-140, 'score': 480.4, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 93259, 'ali to flip': 94509}
# Hit B: {'target name': 'k127_748425', 'accession': '-', 'query name': 'Q8GB19', 'accession1': '-', 'hmm len': 406, 'hmm from': 11, 'hmm to': 209, 'seq len': 125518, 'ali from': 94509, 'ali to': 93883, 'env from': 94527, 'env to': 93817, 'E-value': 3.8e-14, 'score': 62.7, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 93883, 'ali to flip': 94509}
# Overlap1: 50.11990407673861%, Overlap2: 100.0%
# Choosing Hit A based on E-value
# Begining Comparison:  65
# Comparing:
# Hit A: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P69902', 'accession1': '-', 'hmm len': 416, 'hmm from': 3, 'hmm to': 413, 'seq len': 125518, 'ali from': 94509, 'ali to': 93259, 'env from': 94518, 'env to': 93250, 'E-value': 1.2e-140, 'score': 480.4, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 93259, 'ali to flip': 94509}
# Hit B: {'target name': 'k127_748425', 'accession': '-', 'query name': 'O06644', 'accession1': '-', 'hmm len': 428, 'hmm from': 2, 'hmm to': 420, 'seq len': 125518, 'ali from': 94512, 'ali to': 93274, 'env from': 94515, 'env to': 93256, 'E-value': 4.1000000000000004e-111, 'score': 383.0, 'bias': 0.1, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 93274, 'ali to flip': 94512}
# Overlap1: 98.8009592326139%, Overlap2: 99.75786924939467%
# Choosing Hit A based on E-value
# Begining Comparison:  65
# Comparing:
# Hit A: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P69902', 'accession1': '-', 'hmm len': 416, 'hmm from': 3, 'hmm to': 413, 'seq len': 125518, 'ali from': 94509, 'ali to': 93259, 'env from': 94518, 'env to': 93250, 'E-value': 1.2e-140, 'score': 480.4, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 93259, 'ali to flip': 94509}
# Hit B: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P76518', 'accession1': '-', 'hmm len': 381, 'hmm from': 7, 'hmm to': 211, 'seq len': 125518, 'ali from': 94512, 'ali to': 93886, 'env from': 94524, 'env to': 93868, 'E-value': 2.9e-38, 'score': 139.3, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 93886, 'ali to flip': 94512}
# Overlap1: 49.88009592326139%, Overlap2: 99.52153110047847%
# Choosing Hit A based on E-value
# Begining Comparison:  65
# Comparing:
# Hit A: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P69902', 'accession1': '-', 'hmm len': 416, 'hmm from': 3, 'hmm to': 413, 'seq len': 125518, 'ali from': 94509, 'ali to': 93259, 'env from': 94518, 'env to': 93250, 'E-value': 1.2e-140, 'score': 480.4, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 93259, 'ali to flip': 94509}
# Hit B: {'target name': 'k127_748425', 'accession': '-', 'query name': 'Q1KLK1', 'accession1': '-', 'hmm len': 428, 'hmm from': 31, 'hmm to': 411, 'seq len': 125518, 'ali from': 94512, 'ali to': 93298, 'env from': 94529, 'env to': 93254, 'E-value': 2.3e-26, 'score': 108.8, 'bias': 0.0, 'shifts': 8, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 93298, 'ali to flip': 94512}
# Overlap1: 96.88249400479616%, Overlap2: 99.75308641975309%
# Choosing Hit A based on E-value
# Begining Comparison:  65
# Comparing:
# Hit A: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P69902', 'accession1': '-', 'hmm len': 416, 'hmm from': 3, 'hmm to': 413, 'seq len': 125518, 'ali from': 94509, 'ali to': 93259, 'env from': 94518, 'env to': 93250, 'E-value': 1.2e-140, 'score': 480.4, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 93259, 'ali to flip': 94509}
# Hit B: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P96877', 'accession1': '-', 'hmm len': 394, 'hmm from': 6, 'hmm to': 386, 'seq len': 125518, 'ali from': 94515, 'ali to': 93322, 'env from': 94530, 'env to': 93301, 'E-value': 7.2e-29, 'score': 111.7, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 93322, 'ali to flip': 94515}
# Overlap1: 94.96402877697841%, Overlap2: 99.49748743718592%
# Choosing Hit A based on E-value
# Begining Comparison:  65
# Comparing:
# Hit A: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P69902', 'accession1': '-', 'hmm len': 416, 'hmm from': 3, 'hmm to': 413, 'seq len': 125518, 'ali from': 94509, 'ali to': 93259, 'env from': 94518, 'env to': 93250, 'E-value': 1.2e-140, 'score': 480.4, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 93259, 'ali to flip': 94509}
# Hit B: {'target name': 'k127_748425', 'accession': '-', 'query name': 'Q93AM1', 'accession1': '-', 'hmm len': 412, 'hmm from': 4, 'hmm to': 215, 'seq len': 125518, 'ali from': 94515, 'ali to': 93886, 'env from': 94524, 'env to': 93808, 'E-value': 3e-18, 'score': 77.6, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 93886, 'ali to flip': 94515}
# Overlap1: 49.88009592326139%, Overlap2: 99.04761904761905%
# Choosing Hit A based on E-value
# Begining Comparison:  65
# Comparing:
# Hit A: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P69902', 'accession1': '-', 'hmm len': 416, 'hmm from': 3, 'hmm to': 413, 'seq len': 125518, 'ali from': 94509, 'ali to': 93259, 'env from': 94518, 'env to': 93250, 'E-value': 1.2e-140, 'score': 480.4, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 93259, 'ali to flip': 94509}
# Hit B: {'target name': 'k127_748425', 'accession': '-', 'query name': 'A6W2K8', 'accession1': '-', 'hmm len': 837, 'hmm from': 4, 'hmm to': 194, 'seq len': 125518, 'ali from': 94518, 'ali to': 93919, 'env from': 94524, 'env to': 93883, 'E-value': 7.5e-14, 'score': 61.3, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 93919, 'ali to flip': 94518}
# Overlap1: 47.24220623501199%, Overlap2: 98.5%
# Choosing Hit A based on E-value
# Begining Comparison:  65
# Comparing:
# Hit A: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P69902', 'accession1': '-', 'hmm len': 416, 'hmm from': 3, 'hmm to': 413, 'seq len': 125518, 'ali from': 94509, 'ali to': 93259, 'env from': 94518, 'env to': 93250, 'E-value': 1.2e-140, 'score': 480.4, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 93259, 'ali to flip': 94509}
# Hit B: {'target name': 'k127_748425', 'accession': '-', 'query name': 'Q1KLK0', 'accession1': '-', 'hmm len': 405, 'hmm from': 4, 'hmm to': 398, 'seq len': 125518, 'ali from': 94521, 'ali to': 93271, 'env from': 94531, 'env to': 93253, 'E-value': 5.8e-36, 'score': 140.5, 'bias': 0.0, 'shifts': 7, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 93271, 'ali to flip': 94521}
# Overlap1: 99.04076738609112%, Overlap2: 99.04076738609112%
# Choosing Hit A based on E-value
# Begining Comparison:  65
# Comparing:
# Hit A: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P69902', 'accession1': '-', 'hmm len': 416, 'hmm from': 3, 'hmm to': 413, 'seq len': 125518, 'ali from': 94509, 'ali to': 93259, 'env from': 94518, 'env to': 93250, 'E-value': 1.2e-140, 'score': 480.4, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 93259, 'ali to flip': 94509}
# Hit B: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P14949', 'accession1': '-', 'hmm len': 104, 'hmm from': 20, 'hmm to': 103, 'seq len': 125518, 'ali from': 97318, 'ali to': 97067, 'env from': 97367, 'env to': 97061, 'E-value': 9.8e-19, 'score': 85.2, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 97067, 'ali to flip': 97318}
# Overlap1: 0.0%, Overlap2: 0.0%
# No significant overlap or both hits retained
# Begining Comparison:  66
# Comparing:
# Hit A: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P14949', 'accession1': '-', 'hmm len': 104, 'hmm from': 20, 'hmm to': 103, 'seq len': 125518, 'ali from': 97318, 'ali to': 97067, 'env from': 97367, 'env to': 97061, 'E-value': 9.8e-19, 'score': 85.2, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 97067, 'ali to flip': 97318}
# Hit B: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P0AA27', 'accession1': '-', 'hmm len': 109, 'hmm from': 20, 'hmm to': 97, 'seq len': 125518, 'ali from': 97330, 'ali to': 97097, 'env from': 97381, 'env to': 97058, 'E-value': 2.2e-15, 'score': 74.4, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 97097, 'ali to flip': 97330}
# Overlap1: 88.09523809523809%, Overlap2: 94.87179487179486%
# Choosing Hit A based on E-value
# Begining Comparison:  66
# Comparing:
# Hit A: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P14949', 'accession1': '-', 'hmm len': 104, 'hmm from': 20, 'hmm to': 103, 'seq len': 125518, 'ali from': 97318, 'ali to': 97067, 'env from': 97367, 'env to': 97061, 'E-value': 9.8e-19, 'score': 85.2, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 97067, 'ali to flip': 97318}
# Hit B: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P9WG67', 'accession1': '-', 'hmm len': 116, 'hmm from': 20, 'hmm to': 111, 'seq len': 125518, 'ali from': 97342, 'ali to': 97067, 'env from': 97382, 'env to': 97052, 'E-value': 2.6e-20, 'score': 90.4, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 97067, 'ali to flip': 97342}
# Overlap1: 100.0%, Overlap2: 91.30434782608695%
# Choosing Hit B based on E-value
# Begining Comparison:  67
# Comparing:
# Hit A: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P9WG67', 'accession1': '-', 'hmm len': 116, 'hmm from': 20, 'hmm to': 111, 'seq len': 125518, 'ali from': 97342, 'ali to': 97067, 'env from': 97382, 'env to': 97052, 'E-value': 2.6e-20, 'score': 90.4, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 97067, 'ali to flip': 97342}
# Hit B: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P52231', 'accession1': '-', 'hmm len': 107, 'hmm from': 12, 'hmm to': 107, 'seq len': 125518, 'ali from': 97348, 'ali to': 97064, 'env from': 97382, 'env to': 97061, 'E-value': 1.3e-18, 'score': 85.1, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 97064, 'ali to flip': 97348}
# Overlap1: 100.0%, Overlap2: 96.84210526315789%
# Choosing Hit A based on E-value
# Begining Comparison:  67
# Comparing:
# Hit A: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P9WG67', 'accession1': '-', 'hmm len': 116, 'hmm from': 20, 'hmm to': 111, 'seq len': 125518, 'ali from': 97342, 'ali to': 97067, 'env from': 97382, 'env to': 97052, 'E-value': 2.6e-20, 'score': 90.4, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 97067, 'ali to flip': 97342}
# Hit B: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P07887', 'accession1': '-', 'hmm len': 108, 'hmm from': 13, 'hmm to': 105, 'seq len': 125518, 'ali from': 97348, 'ali to': 97073, 'env from': 97385, 'env to': 97061, 'E-value': 3.3e-16, 'score': 76.9, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 97073, 'ali to flip': 97348}
# Overlap1: 97.82608695652173%, Overlap2: 97.82608695652173%
# Choosing Hit A based on E-value
# Begining Comparison:  67
# Comparing:
# Hit A: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P9WG67', 'accession1': '-', 'hmm len': 116, 'hmm from': 20, 'hmm to': 111, 'seq len': 125518, 'ali from': 97342, 'ali to': 97067, 'env from': 97382, 'env to': 97052, 'E-value': 2.6e-20, 'score': 90.4, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 97067, 'ali to flip': 97342}
# Hit B: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P00275', 'accession1': '-', 'hmm len': 105, 'hmm from': 9, 'hmm to': 97, 'seq len': 125518, 'ali from': 97351, 'ali to': 97088, 'env from': 97379, 'env to': 97065, 'E-value': 4.8e-17, 'score': 79.8, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 97088, 'ali to flip': 97351}
# Overlap1: 92.3913043478261%, Overlap2: 96.5909090909091%
# Choosing Hit A based on E-value
# Begining Comparison:  67
# Comparing:
# Hit A: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P9WG67', 'accession1': '-', 'hmm len': 116, 'hmm from': 20, 'hmm to': 111, 'seq len': 125518, 'ali from': 97342, 'ali to': 97067, 'env from': 97382, 'env to': 97052, 'E-value': 2.6e-20, 'score': 90.4, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 97067, 'ali to flip': 97342}
# Hit B: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P10472', 'accession1': '-', 'hmm len': 108, 'hmm from': 11, 'hmm to': 108, 'seq len': 125518, 'ali from': 97351, 'ali to': 97061, 'env from': 97379, 'env to': 97058, 'E-value': 1.4e-16, 'score': 78.2, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 97061, 'ali to flip': 97351}
# Overlap1: 100.0%, Overlap2: 94.84536082474226%
# Choosing Hit A based on E-value
# Begining Comparison:  67
# Comparing:
# Hit A: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P9WG67', 'accession1': '-', 'hmm len': 116, 'hmm from': 20, 'hmm to': 111, 'seq len': 125518, 'ali from': 97342, 'ali to': 97067, 'env from': 97382, 'env to': 97052, 'E-value': 2.6e-20, 'score': 90.4, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 97067, 'ali to flip': 97342}
# Hit B: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P10473', 'accession1': '-', 'hmm len': 104, 'hmm from': 8, 'hmm to': 92, 'seq len': 125518, 'ali from': 97351, 'ali to': 97100, 'env from': 97378, 'env to': 97056, 'E-value': 1.2e-15, 'score': 75.4, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 97100, 'ali to flip': 97351}
# Overlap1: 88.04347826086956%, Overlap2: 96.42857142857143%
# Choosing Hit A based on E-value
# Begining Comparison:  67
# Comparing:
# Hit A: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P9WG67', 'accession1': '-', 'hmm len': 116, 'hmm from': 20, 'hmm to': 111, 'seq len': 125518, 'ali from': 97342, 'ali to': 97067, 'env from': 97382, 'env to': 97052, 'E-value': 2.6e-20, 'score': 90.4, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 97067, 'ali to flip': 97342}
# Hit B: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P08058', 'accession1': '-', 'hmm len': 106, 'hmm from': 10, 'hmm to': 99, 'seq len': 125518, 'ali from': 97351, 'ali to': 97085, 'env from': 97381, 'env to': 97067, 'E-value': 1.5e-12, 'score': 65.2, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 97085, 'ali to flip': 97351}
# Overlap1: 93.47826086956522%, Overlap2: 96.62921348314607%
# Choosing Hit A based on E-value
# Begining Comparison:  67
# Comparing:
# Hit A: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P9WG67', 'accession1': '-', 'hmm len': 116, 'hmm from': 20, 'hmm to': 111, 'seq len': 125518, 'ali from': 97342, 'ali to': 97067, 'env from': 97382, 'env to': 97052, 'E-value': 2.6e-20, 'score': 90.4, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 97067, 'ali to flip': 97342}
# Hit B: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P52232', 'accession1': '-', 'hmm len': 105, 'hmm from': 9, 'hmm to': 104, 'seq len': 125518, 'ali from': 97354, 'ali to': 97067, 'env from': 97381, 'env to': 97061, 'E-value': 1.2e-25, 'score': 107.3, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 97067, 'ali to flip': 97354}
# Overlap1: 100.0%, Overlap2: 95.83333333333334%
# Choosing Hit B based on E-value
# Begining Comparison:  68
# Comparing:
# Hit A: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P52232', 'accession1': '-', 'hmm len': 105, 'hmm from': 9, 'hmm to': 104, 'seq len': 125518, 'ali from': 97354, 'ali to': 97067, 'env from': 97381, 'env to': 97061, 'E-value': 1.2e-25, 'score': 107.3, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 97067, 'ali to flip': 97354}
# Hit B: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P0AGG4', 'accession1': '-', 'hmm len': 139, 'hmm from': 43, 'hmm to': 137, 'seq len': 125518, 'ali from': 97354, 'ali to': 97070, 'env from': 97382, 'env to': 97059, 'E-value': 3.1e-13, 'score': 67.7, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 97070, 'ali to flip': 97354}
# Overlap1: 98.95833333333334%, Overlap2: 100.0%
# Choosing Hit A based on E-value
# Begining Comparison:  68
# Comparing:
# Hit A: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P52232', 'accession1': '-', 'hmm len': 105, 'hmm from': 9, 'hmm to': 104, 'seq len': 125518, 'ali from': 97354, 'ali to': 97067, 'env from': 97381, 'env to': 97061, 'E-value': 1.2e-25, 'score': 107.3, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 97067, 'ali to flip': 97354}
# Hit B: {'target name': 'k127_748425', 'accession': '-', 'query name': 'Q7M1B9', 'accession1': '-', 'hmm len': 110, 'hmm from': 9, 'hmm to': 95, 'seq len': 125518, 'ali from': 97357, 'ali to': 97100, 'env from': 97385, 'env to': 97059, 'E-value': 1.2e-14, 'score': 71.8, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 97100, 'ali to flip': 97357}
# Overlap1: 88.54166666666666%, Overlap2: 98.83720930232558%
# Choosing Hit A based on E-value
# Begining Comparison:  68
# Comparing:
# Hit A: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P52232', 'accession1': '-', 'hmm len': 105, 'hmm from': 9, 'hmm to': 104, 'seq len': 125518, 'ali from': 97354, 'ali to': 97067, 'env from': 97381, 'env to': 97061, 'E-value': 1.2e-25, 'score': 107.3, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 97067, 'ali to flip': 97354}
# Hit B: {'target name': 'k127_748425', 'accession': '-', 'query name': 'O30974', 'accession1': '-', 'hmm len': 112, 'hmm from': 11, 'hmm to': 110, 'seq len': 125518, 'ali from': 97360, 'ali to': 97070, 'env from': 97382, 'env to': 97061, 'E-value': 2.2e-21, 'score': 93.8, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 97070, 'ali to flip': 97360}
# Overlap1: 98.95833333333334%, Overlap2: 97.9381443298969%
# Choosing Hit A based on E-value
# Begining Comparison:  68
# Comparing:
# Hit A: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P52232', 'accession1': '-', 'hmm len': 105, 'hmm from': 9, 'hmm to': 104, 'seq len': 125518, 'ali from': 97354, 'ali to': 97067, 'env from': 97381, 'env to': 97061, 'E-value': 1.2e-25, 'score': 107.3, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 97067, 'ali to flip': 97354}
# Hit B: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P80579', 'accession1': '-', 'hmm len': 105, 'hmm from': 5, 'hmm to': 102, 'seq len': 125518, 'ali from': 97363, 'ali to': 97070, 'env from': 97379, 'env to': 97059, 'E-value': 1.3e-21, 'score': 94.8, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 97070, 'ali to flip': 97363}
# Overlap1: 98.95833333333334%, Overlap2: 96.93877551020408%
# Choosing Hit A based on E-value
# Begining Comparison:  68
# Comparing:
# Hit A: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P52232', 'accession1': '-', 'hmm len': 105, 'hmm from': 9, 'hmm to': 104, 'seq len': 125518, 'ali from': 97354, 'ali to': 97067, 'env from': 97381, 'env to': 97061, 'E-value': 1.2e-25, 'score': 107.3, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 97067, 'ali to flip': 97354}
# Hit B: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P52230', 'accession1': '-', 'hmm len': 110, 'hmm from': 8, 'hmm to': 108, 'seq len': 125518, 'ali from': 97363, 'ali to': 97064, 'env from': 97385, 'env to': 97055, 'E-value': 1e-16, 'score': 78.4, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 97064, 'ali to flip': 97363}
# Overlap1: 100.0%, Overlap2: 96.0%
# Choosing Hit A based on E-value
# Begining Comparison:  68
# Comparing:
# Hit A: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P52232', 'accession1': '-', 'hmm len': 105, 'hmm from': 9, 'hmm to': 104, 'seq len': 125518, 'ali from': 97354, 'ali to': 97067, 'env from': 97381, 'env to': 97061, 'E-value': 1.2e-25, 'score': 107.3, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 97067, 'ali to flip': 97354}
# Hit B: {'target name': 'k127_748425', 'accession': '-', 'query name': 'Q05739', 'accession1': '-', 'hmm len': 107, 'hmm from': 8, 'hmm to': 100, 'seq len': 125518, 'ali from': 97363, 'ali to': 97085, 'env from': 97385, 'env to': 97059, 'E-value': 1.9e-13, 'score': 68.1, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 97085, 'ali to flip': 97363}
# Overlap1: 93.75%, Overlap2: 96.7741935483871%
# Choosing Hit A based on E-value
# Begining Comparison:  68
# Comparing:
# Hit A: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P52232', 'accession1': '-', 'hmm len': 105, 'hmm from': 9, 'hmm to': 104, 'seq len': 125518, 'ali from': 97354, 'ali to': 97067, 'env from': 97381, 'env to': 97061, 'E-value': 1.2e-25, 'score': 107.3, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 97067, 'ali to flip': 97354}
# Hit B: {'target name': 'k127_748425', 'accession': '-', 'query name': 'Q2FZD2', 'accession1': '-', 'hmm len': 104, 'hmm from': 5, 'hmm to': 103, 'seq len': 125518, 'ali from': 97366, 'ali to': 97067, 'env from': 97379, 'env to': 97061, 'E-value': 8.4e-22, 'score': 94.9, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 97067, 'ali to flip': 97366}
# Overlap1: 100.0%, Overlap2: 96.0%
# Choosing Hit A based on E-value
# Begining Comparison:  68
# Comparing:
# Hit A: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P52232', 'accession1': '-', 'hmm len': 105, 'hmm from': 9, 'hmm to': 104, 'seq len': 125518, 'ali from': 97354, 'ali to': 97067, 'env from': 97381, 'env to': 97061, 'E-value': 1.2e-25, 'score': 107.3, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 97067, 'ali to flip': 97354}
# Hit B: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P73263', 'accession1': '-', 'hmm len': 109, 'hmm from': 5, 'hmm to': 104, 'seq len': 125518, 'ali from': 97366, 'ali to': 97070, 'env from': 97375, 'env to': 97058, 'E-value': 9.4e-15, 'score': 69.1, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 97070, 'ali to flip': 97366}
# Overlap1: 98.95833333333334%, Overlap2: 95.95959595959596%
# Choosing Hit A based on E-value
# Begining Comparison:  68
# Comparing:
# Hit A: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P52232', 'accession1': '-', 'hmm len': 105, 'hmm from': 9, 'hmm to': 104, 'seq len': 125518, 'ali from': 97354, 'ali to': 97067, 'env from': 97381, 'env to': 97061, 'E-value': 1.2e-25, 'score': 107.3, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 97067, 'ali to flip': 97354}
# Hit B: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P09857', 'accession1': '-', 'hmm len': 107, 'hmm from': 6, 'hmm to': 101, 'seq len': 125518, 'ali from': 97366, 'ali to': 97082, 'env from': 97384, 'env to': 97062, 'E-value': 2.5e-14, 'score': 71.6, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 97082, 'ali to flip': 97366}
# Overlap1: 94.79166666666666%, Overlap2: 95.78947368421052%
# Choosing Hit A based on E-value
# Begining Comparison:  68
# Comparing:
# Hit A: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P52232', 'accession1': '-', 'hmm len': 105, 'hmm from': 9, 'hmm to': 104, 'seq len': 125518, 'ali from': 97354, 'ali to': 97067, 'env from': 97381, 'env to': 97061, 'E-value': 1.2e-25, 'score': 107.3, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 97067, 'ali to flip': 97354}
# Hit B: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P0A4L2', 'accession1': '-', 'hmm len': 107, 'hmm from': 5, 'hmm to': 105, 'seq len': 125518, 'ali from': 97369, 'ali to': 97070, 'env from': 97388, 'env to': 97061, 'E-value': 9e-18, 'score': 82.2, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 97070, 'ali to flip': 97369}
# Overlap1: 98.95833333333334%, Overlap2: 95.0%
# Choosing Hit A based on E-value
# Begining Comparison:  68
# Comparing:
# Hit A: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P52232', 'accession1': '-', 'hmm len': 105, 'hmm from': 9, 'hmm to': 104, 'seq len': 125518, 'ali from': 97354, 'ali to': 97067, 'env from': 97381, 'env to': 97061, 'E-value': 1.2e-25, 'score': 107.3, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 97067, 'ali to flip': 97354}
# Hit B: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P66928', 'accession1': '-', 'hmm len': 106, 'hmm from': 5, 'hmm to': 106, 'seq len': 125518, 'ali from': 97369, 'ali to': 97061, 'env from': 97388, 'env to': 97058, 'E-value': 9.1e-16, 'score': 75.7, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 97061, 'ali to flip': 97369}
# Overlap1: 100.0%, Overlap2: 93.20388349514563%
# Choosing Hit A based on E-value
# Begining Comparison:  68
# Comparing:
# Hit A: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P52232', 'accession1': '-', 'hmm len': 105, 'hmm from': 9, 'hmm to': 104, 'seq len': 125518, 'ali from': 97354, 'ali to': 97067, 'env from': 97381, 'env to': 97061, 'E-value': 1.2e-25, 'score': 107.3, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 97067, 'ali to flip': 97354}
# Hit B: {'target name': 'k127_748425', 'accession': '-', 'query name': 'Q9RD25', 'accession1': '-', 'hmm len': 134, 'hmm from': 2, 'hmm to': 92, 'seq len': 125518, 'ali from': 97378, 'ali to': 97103, 'env from': 97381, 'env to': 97058, 'E-value': 1.4e-09, 'score': 52.5, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 97103, 'ali to flip': 97378}
# Overlap1: 87.5%, Overlap2: 91.30434782608695%
# Choosing Hit A based on E-value
# Begining Comparison:  68
# Comparing:
# Hit A: {'target name': 'k127_748425', 'accession': '-', 'query name': 'P52232', 'accession1': '-', 'hmm len': 105, 'hmm from': 9, 'hmm to': 104, 'seq len': 125518, 'ali from': 97354, 'ali to': 97067, 'env from': 97381, 'env to': 97061, 'E-value': 1.2e-25, 'score': 107.3, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 97067, 'ali to flip': 97354}
# Hit B: {'target name': 'k127_748425', 'accession': '-', 'query name': 'Q8E9K5', 'accession1': '-', 'hmm len': 372, 'hmm from': 144, 'hmm to': 246, 'seq len': 125518, 'ali from': 100766, 'ali to': 100449, 'env from': 101075, 'env to': 100103, 'E-value': 2.4e-09, 'score': 53.5, 'bias': 0.0, 'shifts': 2, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 100449, 'ali to flip': 100766}
# Overlap1: 0.0%, Overlap2: 0.0%
# No significant overlap or both hits retained
# Begining Comparison:  69
# Comparing:
# Hit A: {'target name': 'k127_748425', 'accession': '-', 'query name': 'Q8E9K5', 'accession1': '-', 'hmm len': 372, 'hmm from': 144, 'hmm to': 246, 'seq len': 125518, 'ali from': 100766, 'ali to': 100449, 'env from': 101075, 'env to': 100103, 'E-value': 2.4e-09, 'score': 53.5, 'bias': 0.0, 'shifts': 2, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 100449, 'ali to flip': 100766}
# Hit B: {'target name': 'k127_748425', 'accession': '-', 'query name': 'Q9K0V1', 'accession1': '-', 'hmm len': 369, 'hmm from': 54, 'hmm to': 346, 'seq len': 125518, 'ali from': 101045, 'ali to': 100137, 'env from': 101090, 'env to': 100083, 'E-value': 1.2e-08, 'score': 48.1, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 100137, 'ali to flip': 101045}
# Overlap1: 100.0%, Overlap2: 34.98349834983499%
# Choosing Hit A based on E-value
# Begining Comparison:  69
# Comparing:
# Hit A: {'target name': 'k127_748425', 'accession': '-', 'query name': 'Q8E9K5', 'accession1': '-', 'hmm len': 372, 'hmm from': 144, 'hmm to': 246, 'seq len': 125518, 'ali from': 100766, 'ali to': 100449, 'env from': 101075, 'env to': 100103, 'E-value': 2.4e-09, 'score': 53.5, 'bias': 0.0, 'shifts': 2, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 100449, 'ali to flip': 100766}
# Hit B: {'target name': 'k127_748425', 'accession': '-', 'query name': 'S5FU55', 'accession1': '-', 'hmm len': 199, 'hmm from': 26, 'hmm to': 181, 'seq len': 125518, 'ali from': 111636, 'ali to': 111181, 'env from': 111699, 'env to': 111178, 'E-value': 2.2e-14, 'score': 65.3, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 111181, 'ali to flip': 111636}
# Overlap1: 0.0%, Overlap2: 0.0%
# No significant overlap or both hits retained
# Begining Comparison:  70
# Comparing:
# ...
# Hit B: {'target name': 'k127_922904', 'accession': '-', 'query name': 'Q45582', 'accession1': '-', 'hmm len': 304, 'hmm from': 17, 'hmm to': 261, 'seq len': 133853, 'ali from': 60433, 'ali to': 59702, 'env from': 60457, 'env to': 59648, 'E-value': 7e-58, 'score': 209.0, 'bias': 0.3, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 59702, 'ali to flip': 60433}
# Overlap1: 100.0%, Overlap2: 94.67213114754098%
# Choosing Hit A based on E-value
# Begining Comparison:  15
# Comparing:
# Hit A: {'target name': 'k127_922904', 'accession': '-', 'query name': 'P44862', 'accession1': '-', 'hmm len': 303, 'hmm from': 21, 'hmm to': 251, 'seq len': 133853, 'ali from': 60427, 'ali to': 59735, 'env from': 60463, 'env to': 59684, 'E-value': 4.2999999999999995e-69, 'score': 245.5, 'bias': 0.1, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 59735, 'ali to flip': 60427}
# Hit B: {'target name': 'k127_922904', 'accession': '-', 'query name': 'Q57252', 'accession1': '-', 'hmm len': 1027, 'hmm from': 39, 'hmm to': 325, 'seq len': 133853, 'ali from': 65395, 'ali to': 64556, 'env from': 65428, 'env to': 64472, 'E-value': 7.2e-15, 'score': 65.8, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 64556, 'ali to flip': 65395}
# Overlap1: 0.0%, Overlap2: 0.0%
# No significant overlap or both hits retained
# Begining Comparison:  16
# Comparing:
# Hit A: {'target name': 'k127_922904', 'accession': '-', 'query name': 'Q57252', 'accession1': '-', 'hmm len': 1027, 'hmm from': 39, 'hmm to': 325, 'seq len': 133853, 'ali from': 65395, 'ali to': 64556, 'env from': 65428, 'env to': 64472, 'E-value': 7.2e-15, 'score': 65.8, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 64556, 'ali to flip': 65395}
# Hit B: {'target name': 'k127_922904', 'accession': '-', 'query name': 'P64592', 'accession1': '-', 'hmm len': 118, 'hmm from': 9, 'hmm to': 113, 'seq len': 133853, 'ali from': 87488, 'ali to': 87186, 'env from': 87503, 'env to': 87177, 'E-value': 4.5e-16, 'score': 74.4, 'bias': 2.1, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 87186, 'ali to flip': 87488}
# Overlap1: 0.0%, Overlap2: 0.0%
# No significant overlap or both hits retained
# Begining Comparison:  17
# Comparing:
# Hit A: {'target name': 'k127_922904', 'accession': '-', 'query name': 'P64592', 'accession1': '-', 'hmm len': 118, 'hmm from': 9, 'hmm to': 113, 'seq len': 133853, 'ali from': 87488, 'ali to': 87186, 'env from': 87503, 'env to': 87177, 'E-value': 4.5e-16, 'score': 74.4, 'bias': 2.1, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 87186, 'ali to flip': 87488}
# Hit B: {'target name': 'k127_922904', 'accession': '-', 'query name': 'Q82UI9', 'accession1': '-', 'hmm len': 151, 'hmm from': 3, 'hmm to': 148, 'seq len': 133853, 'ali from': 91038, 'ali to': 90601, 'env from': 91044, 'env to': 90592, 'E-value': 9.1e-14, 'score': 57.7, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 90601, 'ali to flip': 91038}
# Overlap1: 0.0%, Overlap2: 0.0%
# No significant overlap or both hits retained
# Begining Comparison:  18
# Comparing:
# Hit A: {'target name': 'k127_922904', 'accession': '-', 'query name': 'Q82UI9', 'accession1': '-', 'hmm len': 151, 'hmm from': 3, 'hmm to': 148, 'seq len': 133853, 'ali from': 91038, 'ali to': 90601, 'env from': 91044, 'env to': 90592, 'E-value': 9.1e-14, 'score': 57.7, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 90601, 'ali to flip': 91038}
# Hit B: {'target name': 'k127_922904', 'accession': '-', 'query name': 'A3DIJ8', 'accession1': '-', 'hmm len': 156, 'hmm from': 1, 'hmm to': 147, 'seq len': 133853, 'ali from': 91047, 'ali to': 90604, 'env from': 91047, 'env to': 90589, 'E-value': 2.7e-34, 'score': 124.6, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 90604, 'ali to flip': 91047}
# Overlap1: 99.31506849315068%, Overlap2: 97.97297297297297%
# Choosing Hit B based on E-value
# Begining Comparison:  19
# Comparing:
# Hit A: {'target name': 'k127_922904', 'accession': '-', 'query name': 'A3DIJ8', 'accession1': '-', 'hmm len': 156, 'hmm from': 1, 'hmm to': 147, 'seq len': 133853, 'ali from': 91047, 'ali to': 90604, 'env from': 91047, 'env to': 90589, 'E-value': 2.7e-34, 'score': 124.6, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 90604, 'ali to flip': 91047}
# Hit B: {'target name': 'k127_922904', 'accession': '-', 'query name': 'A0A140NCB4', 'accession1': '-', 'hmm len': 262, 'hmm from': 94, 'hmm to': 252, 'seq len': 133853, 'ali from': 104253, 'ali to': 103777, 'env from': 104331, 'env to': 103771, 'E-value': 1.5e-15, 'score': 71.3, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 103777, 'ali to flip': 104253}
# Overlap1: 0.0%, Overlap2: 0.0%
# No significant overlap or both hits retained
# Begining Comparison:  20
# Comparing:
# Hit A: {'target name': 'k127_922904', 'accession': '-', 'query name': 'A0A140NCB4', 'accession1': '-', 'hmm len': 262, 'hmm from': 94, 'hmm to': 252, 'seq len': 133853, 'ali from': 104253, 'ali to': 103777, 'env from': 104331, 'env to': 103771, 'E-value': 1.5e-15, 'score': 71.3, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 103777, 'ali to flip': 104253}
# Hit B: {'target name': 'k127_922904', 'accession': '-', 'query name': 'P0DP65', 'accession1': '-', 'hmm len': 261, 'hmm from': 30, 'hmm to': 252, 'seq len': 133853, 'ali from': 104463, 'ali to': 103780, 'env from': 104541, 'env to': 103771, 'E-value': 6.9e-21, 'score': 88.5, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 103780, 'ali to flip': 104463}
# Overlap1: 99.37106918238993%, Overlap2: 69.2982456140351%
# Choosing Hit B based on E-value
# Begining Comparison:  21
# Comparing:
# Hit A: {'target name': 'k127_922904', 'accession': '-', 'query name': 'P0DP65', 'accession1': '-', 'hmm len': 261, 'hmm from': 30, 'hmm to': 252, 'seq len': 133853, 'ali from': 104463, 'ali to': 103780, 'env from': 104541, 'env to': 103771, 'E-value': 6.9e-21, 'score': 88.5, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 103780, 'ali to flip': 104463}
# Hit B: {'target name': 'k127_922904', 'accession': '-', 'query name': 'Q75SP7', 'accession1': '-', 'hmm len': 274, 'hmm from': 24, 'hmm to': 249, 'seq len': 133853, 'ali from': 104478, 'ali to': 103774, 'env from': 104523, 'env to': 103771, 'E-value': 1.7e-09, 'score': 50.9, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 103774, 'ali to flip': 104478}
# Overlap1: 100.0%, Overlap2: 97.02127659574468%
# Choosing Hit A based on E-value
# Begining Comparison:  21
# Comparing:
# Hit A: {'target name': 'k127_922904', 'accession': '-', 'query name': 'P0DP65', 'accession1': '-', 'hmm len': 261, 'hmm from': 30, 'hmm to': 252, 'seq len': 133853, 'ali from': 104463, 'ali to': 103780, 'env from': 104541, 'env to': 103771, 'E-value': 6.9e-21, 'score': 88.5, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 103780, 'ali to flip': 104463}
# Hit B: {'target name': 'k127_922904', 'accession': '-', 'query name': 'P0DP66', 'accession1': '-', 'hmm len': 272, 'hmm from': 19, 'hmm to': 267, 'seq len': 133853, 'ali from': 104499, 'ali to': 103777, 'env from': 104541, 'env to': 103771, 'E-value': 2.6e-12, 'score': 59.7, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 103777, 'ali to flip': 104499}
# Overlap1: 100.0%, Overlap2: 94.6058091286307%
# Choosing Hit A based on E-value
# Begining Comparison:  21
# Comparing:
# Hit A: {'target name': 'k127_922904', 'accession': '-', 'query name': 'P0DP65', 'accession1': '-', 'hmm len': 261, 'hmm from': 30, 'hmm to': 252, 'seq len': 133853, 'ali from': 104463, 'ali to': 103780, 'env from': 104541, 'env to': 103771, 'E-value': 6.9e-21, 'score': 88.5, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 103780, 'ali to flip': 104463}
# Hit B: {'target name': 'k127_922904', 'accession': '-', 'query name': 'P0DP68', 'accession1': '-', 'hmm len': 286, 'hmm from': 15, 'hmm to': 266, 'seq len': 133853, 'ali from': 104511, 'ali to': 103777, 'env from': 104557, 'env to': 103756, 'E-value': 5.5e-09, 'score': 52.4, 'bias': 0.0, 'shifts': 6, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 103777, 'ali to flip': 104511}
# Overlap1: 100.0%, Overlap2: 93.06122448979592%
# Choosing Hit A based on E-value
# Begining Comparison:  21
# Comparing:
# Hit A: {'target name': 'k127_922904', 'accession': '-', 'query name': 'P0DP65', 'accession1': '-', 'hmm len': 261, 'hmm from': 30, 'hmm to': 252, 'seq len': 133853, 'ali from': 104463, 'ali to': 103780, 'env from': 104541, 'env to': 103771, 'E-value': 6.9e-21, 'score': 88.5, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 103780, 'ali to flip': 104463}
# Hit B: {'target name': 'k127_922904', 'accession': '-', 'query name': 'A0A140NDS5', 'accession1': '-', 'hmm len': 256, 'hmm from': 7, 'hmm to': 249, 'seq len': 133853, 'ali from': 104538, 'ali to': 103774, 'env from': 104553, 'env to': 103771, 'E-value': 3.9e-40, 'score': 151.8, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 103774, 'ali to flip': 104538}
# Overlap1: 100.0%, Overlap2: 89.41176470588236%
# Choosing Hit B based on E-value
# Begining Comparison:  22
# Comparing:
# Hit A: {'target name': 'k127_922904', 'accession': '-', 'query name': 'A0A140NDS5', 'accession1': '-', 'hmm len': 256, 'hmm from': 7, 'hmm to': 249, 'seq len': 133853, 'ali from': 104538, 'ali to': 103774, 'env from': 104553, 'env to': 103771, 'E-value': 3.9e-40, 'score': 151.8, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 103774, 'ali to flip': 104538}
# Hit B: {'target name': 'k127_922904', 'accession': '-', 'query name': 'Q93NG1', 'accession1': '-', 'hmm len': 294, 'hmm from': 14, 'hmm to': 276, 'seq len': 133853, 'ali from': 104553, 'ali to': 103774, 'env from': 104580, 'env to': 103771, 'E-value': 4e-19, 'score': 81.6, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 103774, 'ali to flip': 104553}
# Overlap1: 100.0%, Overlap2: 98.07692307692307%
# Choosing Hit A based on E-value
# Begining Comparison:  22
# Comparing:
# Hit A: {'target name': 'k127_922904', 'accession': '-', 'query name': 'A0A140NDS5', 'accession1': '-', 'hmm len': 256, 'hmm from': 7, 'hmm to': 249, 'seq len': 133853, 'ali from': 104538, 'ali to': 103774, 'env from': 104553, 'env to': 103771, 'E-value': 3.9e-40, 'score': 151.8, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 103774, 'ali to flip': 104538}
# Hit B: {'target name': 'k127_922904', 'accession': '-', 'query name': 'P00934', 'accession1': '-', 'hmm len': 428, 'hmm from': 6, 'hmm to': 424, 'seq len': 133853, 'ali from': 106941, 'ali to': 105640, 'env from': 106956, 'env to': 105628, 'E-value': 5.699999999999999e-69, 'score': 246.1, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 105640, 'ali to flip': 106941}
# Overlap1: 0.0%, Overlap2: 0.0%
# No significant overlap or both hits retained
# Begining Comparison:  23
# Comparing:
# Hit A: {'target name': 'k127_922904', 'accession': '-', 'query name': 'P00934', 'accession1': '-', 'hmm len': 428, 'hmm from': 6, 'hmm to': 424, 'seq len': 133853, 'ali from': 106941, 'ali to': 105640, 'env from': 106956, 'env to': 105628, 'E-value': 5.699999999999999e-69, 'score': 246.1, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 105640, 'ali to flip': 106941}
# Hit B: {'target name': 'k127_922904', 'accession': '-', 'query name': 'P23669', 'accession1': '-', 'hmm len': 481, 'hmm from': 1, 'hmm to': 305, 'seq len': 133853, 'ali from': 106956, 'ali to': 106054, 'env from': 106956, 'env to': 105985, 'E-value': 1.1000000000000001e-27, 'score': 110.0, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 106054, 'ali to flip': 106956}
# Overlap1: 68.20276497695853%, Overlap2: 98.33887043189368%
# Choosing Hit A based on E-value
# Begining Comparison:  23
# Comparing:
# Hit A: {'target name': 'k127_922904', 'accession': '-', 'query name': 'P00934', 'accession1': '-', 'hmm len': 428, 'hmm from': 6, 'hmm to': 424, 'seq len': 133853, 'ali from': 106941, 'ali to': 105640, 'env from': 106956, 'env to': 105628, 'E-value': 5.699999999999999e-69, 'score': 246.1, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 105640, 'ali to flip': 106941}
# Hit B: {'target name': 'k127_922904', 'accession': '-', 'query name': 'O51767', 'accession1': '-', 'hmm len': 823, 'hmm from': 6, 'hmm to': 431, 'seq len': 133853, 'ali from': 127984, 'ali to': 126728, 'env from': 127993, 'env to': 126689, 'E-value': 1.3000000000000002e-44, 'score': 163.9, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 126728, 'ali to flip': 127984}
# Overlap1: 0.0%, Overlap2: 0.0%
# No significant overlap or both hits retained
# Begining Comparison:  24
# Comparing:
# Hit A: {'target name': 'k127_922904', 'accession': '-', 'query name': 'O51767', 'accession1': '-', 'hmm len': 823, 'hmm from': 6, 'hmm to': 431, 'seq len': 133853, 'ali from': 127984, 'ali to': 126728, 'env from': 127993, 'env to': 126689, 'E-value': 1.3000000000000002e-44, 'score': 163.9, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 126728, 'ali to flip': 127984}
# Hit B: {'target name': 'k127_922904', 'accession': '-', 'query name': 'P37024', 'accession1': '-', 'hmm len': 809, 'hmm from': 1, 'hmm to': 798, 'seq len': 133853, 'ali from': 127993, 'ali to': 125591, 'env from': 127993, 'env to': 125582, 'E-value': 7.6e-139, 'score': 475.5, 'bias': 7.3, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 125591, 'ali to flip': 127993}
# Overlap1: 100.0%, Overlap2: 52.30961298377028%
# Choosing Hit B based on E-value
# Overlap calculations done on columns: ali from flip ali to flip
# 70% deduplication done.
# Less than 70% deduplication done.
# <ipython-input-3-830c4c50e74a>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ali from'] = df['ali from'].astype(int)
# <ipython-input-3-830c4c50e74a>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ali to'] = df['ali to'].astype(int)

# %%
list_of_dfs = []
for i in glob("/content/*.xlsx"):
  list_of_dfs.append(pd.read_excel(i))

# %%
bathout = pd.concat(list_of_dfs)
df_neg = filtering_operations.get_specific_strand(bathout,"-")
neg_deduped = overlap_deduplications.choose_strand_operations(df_neg)
df_pos = filtering_operations.get_specific_strand(bathout,"+")
pos_deduped = overlap_deduplications.choose_strand_operations(df_pos)
complete_bath_deduplication = pd.concat([pos_deduped,neg_deduped])

# %%
complete_bath_deduplication.to_excel("bin82_BATH_deduplicated.xlsx")

# %%
complete_bath_deduplication.shape
# Out:
# (890, 23)

# %%
import pandas as pd

# Define the path to the newly uploaded file
file_path = '/content/bin82_BATH_deduplicated.xlsx'

df = pd.read_excel(file_path, header=None, skiprows=2)
df.head()
col_names = [
    'target name', 'accession', 'query name', 'accession1', 'hmm len', 'hmm from',
    'hmm to', 'seq len', 'ali from', 'ali to', 'env from', 'env to', 'E-value',
    'score', 'bias', 'shifts', 'stops', 'pipe', 'description of target'
]

# Rename the columns in the DataFrame
df.columns = col_names

# Perform strand specific filtering and deduplication
df_neg = filtering_operations.get_specific_strand(df, "-")
#neg_deduped = overlap_deduplications.choose_strand_operations(df_neg)

df_pos = filtering_operations.get_specific_strand(df, "+")
pos_deduped = overlap_deduplications.choose_strand_operations(df_pos)

# Combine negative and positive strand results
#bath_file_deduplication = pd.concat([pos_deduped, neg_deduped])
bath_file_deduplication['origin'] = file_path.split("/")[-1].split(".txt")[0]

# Save the deduplicated results to an Excel file
output_path = '/content/' + file_path.split("/")[-1].split(".txt")[0] + "_deduplicated.xlsx"
bath_file_deduplication.to_excel(output_path, index=False)

print(f"Data processed and saved to {output_path}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-78654802126c> in <cell line: 15>()
#      13
#      14 # Rename the columns in the DataFrame
# ---> 15 df.columns = col_names
#      16
#      17 # Perform strand specific filtering and deduplication
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    6000         try:
#    6001             object.__getattribute__(self, name)
# -> 6002             return object.__setattr__(self, name, value)
#    6003         except AttributeError:
#    6004             pass
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     728         """
#     729         labels = ensure_index(labels)
# --> 730         self._mgr.set_axis(axis, labels)
#     731         self._clear_item_cache()
#     732
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     223     def set_axis(self, axis: AxisInt, new_labels: Index) -> None:
#     224         # Caller is responsible for ensuring we have an Index object.
# --> 225         self._validate_set_axis(axis, new_labels)
#     226         self.axes[axis] = new_labels
#     227
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/base.py in _validate_set_axis(self, axis, new_labels)
#      68
#      69         elif new_len != old_len:
# ---> 70             raise ValueError(
#      71                 f"Length mismatch: Expected axis has {old_len} elements, new "
#      72                 f"values have {new_len} elements"
#
# ValueError: Length mismatch: Expected axis has 24 elements, new values have 19 elements
