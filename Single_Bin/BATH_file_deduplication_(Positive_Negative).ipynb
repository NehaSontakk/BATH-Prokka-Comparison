# %% [markdown]
# <a href="https://colab.research.google.com/github/NehaSontakk/BATH-Prokka-Comparison/blob/main/Single_Bin/BATH_file_deduplication_(Positive_Negative).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Strand-specific Genomic Data Deduplication Using E-value and Overlap Metrics
#
#
# A method for filtering and deduplicating genomic data is designed to enhance the accuracy and reliability of sequence alignments by leveraging E-value thresholds and alignment overlap metrics. Initially, an E-value threshold of 0.000001 is applied to exclude low-confidence alignments. Subsequently, the DNA strand (positive or negative) is identified based on alignment positions. For each strand, a series of deduplication steps are performed:
#
# *   100% Deduplication: Exact duplicates are identified and removed by comparing E-values and scores, retaining only the highest quality alignments.
# *   70% Deduplication: Alignments with significant overlap (≥70%) are addressed by comparing E-values and sequence lengths, with the more reliable alignment being retained.
# *  <70% Deduplication: For alignments with minor overlap (0.01% to <70%), adjustments are made to the alignment positions to resolve conflicts, ensuring non-redundancy of the retained alignments.
#
# Each deduplication step is applied to ensure that the final dataset is both comprehensive and non-redundant, providing high-confidence data for subsequent analyses. This method is applied separately to positive and negative strands, allowing for tailored processing and accurate strand-specific results.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Input file specification

bathsearch_op_path = "/content/drive/MyDrive/Lab Work/Parkinsons_Data/Iteration_Sep30/BATH_Deduplication/*.tbl"
deduplication_op_path = "/content/drive/MyDrive/Lab Work/Parkinsons_Data/Iteration_Sep30/dedup_combinned_binned_unbinned_sep30.xlsx"

# %%
e_value_threshold = 0.000001

# %%
import pandas as pd
from glob import glob
import os

# %%
class filtering_operations:

  @staticmethod
  def e_value_filtering(df):
    return df.loc[df['E-value']<=e_value_threshold]

  @staticmethod
  def pos_neg_strand_filtering(df_filtered):
    #df should be post e_value_filteration
    df = filtering_operations.e_value_filtering(df_filtered)
    #Strand identification
    df['ali from'] = df['ali from'].astype(int)
    df['ali to'] = df['ali to'].astype(int)
    strand = []

    for index,row in df.iterrows():
      if row['ali from'] < row['ali to']:
        strand.append("+")
      elif row['ali from'] > row['ali to']:
        strand.append("-")

    df['strand'] = strand
    return df

  @staticmethod
  def get_specific_strand(df_raw,strand_info):
    df = filtering_operations.pos_neg_strand_filtering(df_raw)
    return df.loc[df['strand']==strand_info]

# %%
class overlap_deduplications:

  ali_to_column = ""
  ali_from_column = ""

  # Initialize variables to hold counts
  initial_count = 0
  count_after_100 = 0
  count_after_70 = 0
  count_after_less_than_70 = 0

  #METHODS FOR 100% DEDUPLICATION

  @staticmethod
  def handle_group(group):
    #Now for each element in group
    min_e_value = group['E-value'].min()
    #find elements with lowest e-values
    group_min_e = group.loc[group['E-value'] == min_e_value]
    #if group contains a single row save it
    if len(group_min_e) == 1:
      return group_min_e
    #if group contains multiple rows with same e-values check min score
    elif len(group_min_e) > 1:
      print("Group contains multiple rows")
      return group_min_e.iloc[0:1]

  @staticmethod
  def deduplicate_full_overlaps(df):
    #100% Overlap Dedup
    overlap_deduplications.initial_count = df.shape[0]
    overlap_deduplications.count_after_100 = dedup_step1.shape[0]
    print("Number of elements in relevant strand: ",df.shape)
    #Find all the duplicates
    duplicates = df.duplicated(subset=['target name',overlap_deduplications.ali_from_column, overlap_deduplications.ali_to_column], keep=False)
    #make a duplicates df
    duplicates_df = df[duplicates]
    #make a non duplicates df
    not_duplicate_df = df[~duplicates]
    print("Number of exact duplicates or homologs: ",duplicates_df.shape)
    #Sort by E-value and score
    duplicates_df1 = duplicates_df.sort_values(by=['E-value', 'score'], ascending=[True, False])
    deduplicated_remhomologs = duplicates_df1.groupby(['target name',overlap_deduplications.ali_from_column,overlap_deduplications.ali_to_column], group_keys=False).apply(overlap_deduplications.handle_group).reset_index(drop=True)
    #rejion after deduplication
    dedup_step1 = pd.concat([not_duplicate_df,deduplicated_remhomologs]).sort_values(['target name','ali from','E-value'])
    print("Number of elements after removing exact duplicates or homologs: ",dedup_step1.shape)
    print("Elements removed: ",df.shape[0] - dedup_step1.shape[0])
    return dedup_step1

  #METHODS FOR 70% DEDUPLICATION

  @staticmethod
  def calculate_overlap(hit_a, hit_b):
    #print("Overlap calculations done on columns:",overlap_deduplications.ali_from_column,overlap_deduplications.ali_to_column)
    start_a, end_a = hit_a[overlap_deduplications.ali_from_column], hit_a[overlap_deduplications.ali_to_column]
    start_b, end_b = hit_b[overlap_deduplications.ali_from_column], hit_b[overlap_deduplications.ali_to_column]

    overlap_length = max(0, min(end_a, end_b) - max(start_a, start_b) + 1)
    #print(min(end_a, end_b))
    #print(max(start_a, start_b))
    #print("Overlap length",overlap_length)

    length_a = end_a - start_a + 1
    length_b = end_b - start_b + 1

    #print("Length",length_a,length_b)
    if length_a > 0 and length_b > 0:
        overlap_perc_a = (overlap_length / length_a) * 100
        overlap_perc_b = (overlap_length / length_b) * 100
        return overlap_perc_a, overlap_perc_b
    else:
        return 0, 0

  @staticmethod
  def calculate_winner(hit_a, hit_b):
      overlap1, overlap2 = overlap_deduplications.calculate_overlap(hit_a, hit_b)
      print(f"Comparing:\nHit A: {hit_a}\nHit B: {hit_b}\nOverlap1: {overlap1}%, Overlap2: {overlap2}%")

      # Check for significant overlap
      if overlap1 >= 70 or overlap2 >= 70:
          # Determine which hit to retain based on E-value or sequence length on tie
          if hit_a['E-value'] < hit_b['E-value']:
              print("Choosing Hit A based on E-value")
              return hit_a
          elif hit_a['E-value'] > hit_b['E-value']:
              print("Choosing Hit B based on E-value")
              return hit_b
          else:  # E-values are tied, check the sequence length
              if hit_a['seq len'] > hit_b['seq len']:
                  print("E-values tied. Choosing Hit A based on larger sequence length")
                  return hit_a
              else:
                  print("E-values tied. Choosing Hit B based on larger sequence length")
                  return hit_b
      else:
          print("No significant overlap or both hits retained")
          return hit_a, hit_b

  @staticmethod
  def handle_70_overlaps(group):
    # Check if the DataFrame has 1 or fewer rows
    initial_group_count = len(group)
    if len(group) <= 1:
        return group


    items = []
    #print("HIIII")
    #print(group)

    for index, row in group.iterrows():
      row_tuple = row.to_dict()
      items.append(row_tuple)

    i = 0
    all_winners = []

    while i<len(items)-1:
      current = items[i]
      print(current)
      next_item = items[i+1]
      print(next_item)
      print("Begining Comparison: ",i)
      #print(current,"\n",next_item)
      result = overlap_deduplications.calculate_winner(current, next_item)

      #If result is two items append the current item to winners list since overlap of current item with next item is less than 70% so we want to keep both
      if isinstance(result,tuple):
        if result[0] not in all_winners:
          all_winners.append(result[0])
          #print("Tuple returned!")
          #print("Appending: ",result[0])
          #print("All winners currently: ",all_winners)
        #else:
        #  print("Result already in all winners, no appending!")
        i += 1
      else:
        if result == current:
          #print("Result is ",i," element and not ",i+1," popping: ",items[i+1])
          items.pop(i+1)
        else:
          i += 1

      if i >= len(items) - 1 and items[-1] not in all_winners:
        all_winners.append(items[-1])

      final_group_count = len(pd.DataFrame(all_winners))
      overlap_deduplications.count_after_70 += final_group_count


    return pd.DataFrame(all_winners)

  #METHODS FOR LESS THAN 70% DEDUPLICATION
  @staticmethod
  def calculate_below_70_changes(hit_a, hit_b):
    overlap1, overlap2 = overlap_deduplications.calculate_overlap(hit_a, hit_b)
    #print("Overlap 1: ",overlap1)
    if (0.01 <= overlap1 < 70) and (0.01 <= overlap2 < 70):
      if hit_a['E-value'] < hit_b['E-value']:
        print("Case A: A dominates")
        print(hit_a)
        print(hit_b)
        hit_b['ali from'] = hit_a['ali to'] + 1
        #print(hit_b)
        return hit_a, hit_b
      else:
        print("Case B: B dominates")
        print(hit_a)
        print(hit_b)
        hit_a['ali to'] = hit_b['ali from'] - 1
        #print(hit_a)
        #print(hit_b)
        return hit_a, hit_b
    else:
      return hit_a,hit_b

  @staticmethod
  def below_70_overlap(group):
    initial_group_count = len(group)
    if len(group) <= 1:
        print("Length of group less than 1.")
        return group

    items = []
    for index, row in group.iterrows():
      row_tuple = row.to_dict()
      items.append(row_tuple)

    for i in range(0,len(items)-1):
      element1, element2 = overlap_deduplications.calculate_below_70_changes(items[i],items[i+1])
      items[i] = element1
      items[i+1] = element2

    final_group_count = len(pd.DataFrame(items))
    overlap_deduplications.count_after_less_than_70 += final_group_count
    return pd.DataFrame(items)

    @staticmethod
    def get_statistics():
        return {
            "Initial Count": overlap_deduplications.initial_count,
            "Count After 100% Deduplication": overlap_deduplications.count_after_100,
            "Count After 70% Deduplication": overlap_deduplications.count_after_70,
            "Count After <70% Deduplication": overlap_deduplications.count_after_less_than_70
        }

  # FINAL METHOD TO CALL
  @staticmethod
  def choose_strand_operations(df):
    if df['strand'].values[0] == '-':
      print("Processing negative strand data...")
      #create the flip columns
      df['ali from flip'] = df['ali to']
      df['ali to flip'] = df['ali from']
      overlap_deduplications.ali_to_column = 'ali to flip'
      overlap_deduplications.ali_from_column = 'ali from flip'
      #100% dedup
      df = df.sort_values(by=['ali from flip','E-value'], ascending=[True, True])
      print(df)
      step1_dedup = overlap_deduplications.deduplicate_full_overlaps(df)
      print("Overlap calculations done on columns:",overlap_deduplications.ali_from_column,overlap_deduplications.ali_to_column)
      print("100% deduplication done.")
      #70% Overlap
      step2_dedup = step1_dedup.groupby(['target name'], group_keys=False).apply(overlap_deduplications.handle_70_overlaps).reset_index(drop=True)
      print("Overlap calculations done on columns:",overlap_deduplications.ali_from_column,overlap_deduplications.ali_to_column)
      print("70% deduplication done.")
      #Less than 70% overlap
      step3_dedup = step2_dedup.groupby(['target name'], group_keys=False).apply(overlap_deduplications.below_70_overlap).reset_index(drop=True)
      print("Less than 70% deduplication done.")
      #return something final
      return step3_dedup
    elif df['strand'].values[0] == '+':
      print("Processing positive strand data...")
      overlap_deduplications.ali_to_column = 'ali to'
      overlap_deduplications.ali_from_column = 'ali from'
      #100% dedup
      df = df.sort_values(by=['ali from','E-value'], ascending=[True, True])
      print(df)
      step1_dedup = overlap_deduplications.deduplicate_full_overlaps(df)
      print("Overlap calculations done on columns:",overlap_deduplications.ali_from_column,overlap_deduplications.ali_to_column)
      print("100% deduplication done.")
      #70% Overlap
      step2_dedup = step1_dedup.groupby(['target name'], group_keys=False).apply(overlap_deduplications.handle_70_overlaps).reset_index(drop=True)
      print("Overlap calculations done on columns:",overlap_deduplications.ali_from_column,overlap_deduplications.ali_to_column)
      print("70% deduplication done.")
      #Less than 70% overlap
      print(step2_dedup)
      step3_dedup = step2_dedup.groupby(['target name'], group_keys=False).apply(overlap_deduplications.below_70_overlap).reset_index(drop=True)
      print("Less than 70% deduplication done.")
      #return something final
      print(step3_dedup)
      return step3_dedup

# %%
dataframes = []
col_names = [
    'target name', 'accession', 'query name', 'accession1', 'hmm len',
    'hmm from', 'hmm to', 'seq len', 'ali from', 'ali to',
    'env from', 'env to', 'E-value', 'score', 'bias', 'shifts',
    'stops', 'pipe', 'description of target', 'extra'
]
for file_path in glob(bathsearch_op_path):
    # Check if the file is not empty by checking its size
    if os.path.getsize(file_path) == 0:
        print(f"Skipping completely empty file: {file_path}")
        continue

    try:
        # Read the table
        bathout = pd.read_table(file_path, sep="\s+", header=None, skiprows=2, skipfooter=8, engine='python')
    except pd.errors.EmptyDataError:
        print(f"No data to parse from file (possibly headers only): {file_path}")
        continue

    # Check if the DataFrame is empty after reading
    if bathout.empty:
        print(f"Skipping empty file with headers but no data: {file_path}")
        continue

    # Rename the columns
    bathout.rename(columns=dict(zip(bathout.columns, col_names)), inplace=True)

    # Append the DataFrame to the list
    dataframes.append(bathout)

# Concatenate all DataFrames into a single DataFrame
combined_df = pd.concat(dataframes, ignore_index=True)
# Out:
# Skipping completely empty file: /content/drive/MyDrive/Lab Work/Parkinsons_Data/Iteration_Sep30/BATH_Deduplication/DNA_Mitochondria_kingdom_sprot_ct4.tbl
# Skipping completely empty file: /content/drive/MyDrive/Lab Work/Parkinsons_Data/Iteration_Sep30/BATH_Deduplication/DNA_Mitochondria_kingdom_sprot_ct24.tbl
# Skipping completely empty file: /content/drive/MyDrive/Lab Work/Parkinsons_Data/Iteration_Sep30/BATH_Deduplication/DNA_Bacteria_kingdom_sprot.tbl
# Skipping completely empty file: /content/drive/MyDrive/Lab Work/Parkinsons_Data/Iteration_Sep30/BATH_Deduplication/DNA_Mitochondria_kingdom_sprot_ct9.tbl
# Skipping completely empty file: /content/drive/MyDrive/Lab Work/Parkinsons_Data/Iteration_Sep30/BATH_Deduplication/DNA_Mitochondria_kingdom_sprot_ct3.tbl
# Skipping completely empty file: /content/drive/MyDrive/Lab Work/Parkinsons_Data/Iteration_Sep30/BATH_Deduplication/DNA_Mitochondria_kingdom_sprot_ct14.tbl
# Skipping completely empty file: /content/drive/MyDrive/Lab Work/Parkinsons_Data/Iteration_Sep30/BATH_Deduplication/DNA_Mitochondria_kingdom_sprot_ct16.tbl
# Skipping completely empty file: /content/drive/MyDrive/Lab Work/Parkinsons_Data/Iteration_Sep30/BATH_Deduplication/DNA_Mitochondria_kingdom_sprot_ct5.tbl
# Skipping completely empty file: /content/drive/MyDrive/Lab Work/Parkinsons_Data/Iteration_Sep30/BATH_Deduplication/DNA_Mitochondria_kingdom_sprot_ct21.tbl
# Skipping completely empty file: /content/drive/MyDrive/Lab Work/Parkinsons_Data/Iteration_Sep30/BATH_Deduplication/DNA_Mitochondria_kingdom_sprot_ct2.tbl
# Skipping completely empty file: /content/drive/MyDrive/Lab Work/Parkinsons_Data/Iteration_Sep30/BATH_Deduplication/DNA_Mitochondria_kingdom_sprot_ct25.tbl
# Skipping completely empty file: /content/drive/MyDrive/Lab Work/Parkinsons_Data/Iteration_Sep30/BATH_Deduplication/DNA_Mitochondria_kingdom_sprot_ct23.tbl
# Skipping completely empty file: /content/drive/MyDrive/Lab Work/Parkinsons_Data/Iteration_Sep30/BATH_Deduplication/DNA_Mitochondria_kingdom_sprot_ct13.tbl
# Skipping completely empty file: /content/drive/MyDrive/Lab Work/Parkinsons_Data/Iteration_Sep30/BATH_Deduplication/DNA_Mitochondria_kingdom_sprot_ct22.tbl

# %%
df_neg = filtering_operations.get_specific_strand(combined_df,"-")
neg_deduped = overlap_deduplications.choose_strand_operations(df_neg)
df_pos = filtering_operations.get_specific_strand(combined_df,"+")
pos_deduped = overlap_deduplications.choose_strand_operations(df_pos)
complete_bath_deduplication = pd.concat([pos_deduped,neg_deduped])
# Out:
# <ipython-input-15-830c4c50e74a>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ali from'] = df['ali from'].astype(int)
# <ipython-input-15-830c4c50e74a>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ali to'] = df['ali to'].astype(int)
# <ipython-input-15-830c4c50e74a>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['strand'] = strand
# Processing negative strand data...
#                                       target name accession   query name  \
# 363    NODE_29284_length_1157_cov_2.639746_bin.32         -       O57809
# 2249   NODE_25170_length_1830_cov_2.707042_bin.86         -       D4GST8
# 275    NODE_19389_length_1241_cov_2.123103_bin.56         -       O57809
# 16    NODE_49782_length_1160_cov_2.403620_bin.122         -  NG_056058.1
# 1567  NODE_34440_length_1303_cov_1.380609_bin.107         -       D4GST8
# ...                                           ...       ...          ...
# 2105    NODE_4_length_365721_cov_24.056546_bin.85         -       D4GST8
# 1653   NODE_11_length_311821_cov_22.237749_bin.92         -       D4GST8
# 2150   NODE_15_length_269189_cov_20.755609_bin.23         -       D4GST8
# 2155     NODE_3_length_559087_cov_18.660493_bin.2         -       D4GST8
# 1773    NODE_2_length_568972_cov_10.896621_bin.24         -       D4GST8
#
#      accession1  hmm len  hmm from  hmm to  seq len  ali from  ali to  ...  \
# 363           -      325        21     119     1157       306       1  ...
# 2249          -      299         1     147     1830       450       1  ...
# 275           -      325        12     287     1241       865       2  ...
# 16            -      257        39     188     1160       445       2  ...
# 1567          -      299         1     278     1303       840       4  ...
# ...         ...      ...       ...     ...      ...       ...     ...  ...
# 2105          -      299        61     269   365721    228032  227370  ...
# 1653          -      299         3     271   311821    233913  233056  ...
# 2150          -      299         3     274   269189    253835  252954  ...
# 2155          -      299         3     272   559087    320726  319854  ...
# 1773          -      299        49     275   568972    409293  408577  ...
#
#            E-value  score  bias  shifts  stops  pipe  description of target  \
# 363   2.800000e-19   80.6   0.4       0      0   std                      -
# 2249  4.200000e-07   41.8   0.7       0      0   std                      -
# 275   2.000000e-36  137.0   0.0       0      0   std                      -
# 16    6.600000e-15   68.1   0.0       0      0   std                      -
# 1567  1.400000e-49  181.1   0.1       0      0   std                      -
# ...            ...    ...   ...     ...    ...   ...                    ...
# 2105  2.400000e-26  104.9   2.1       0      0   std                      -
# 1653  1.400000e-34  131.9   0.3       0      0   std                      -
# 2150  1.500000e-24   99.0   0.0       0      0   std                      -
# 2155  2.200000e-24   98.5   0.0       0      0   std                      -
# 1773  1.500000e-32  125.3   0.7       0      0   std                      -
#
#      strand ali from flip ali to flip
# 363       -             1         306
# 2249      -             1         450
# 275       -             2         865
# 16        -             2         445
# 1567      -             4         840
# ...     ...           ...         ...
# 2105      -        227370      228032
# 1653      -        233056      233913
# 2150      -        252954      253835
# 2155      -        319854      320726
# 1773      -        408577      409293
#
# [1273 rows x 22 columns]
# Number of elements in relevant strand:  (1273, 22)
# Number of exact duplicates or homologs:  (634, 22)
# Number of elements after removing exact duplicates or homologs:  (956, 22)
# Elements removed:  317
# Overlap calculations done on columns: ali from flip ali to flip
# 100% deduplication done.
# {'target name': 'NODE_10472_length_2081_cov_28.406219_bin.12', 'accession': '-', 'query name': 'IS1000A', 'accession1': '-', 'hmm len': 317, 'hmm from': 156, 'hmm to': 305, 'seq len': 2081, 'ali from': 789, 'ali to': 316, 'env from': 843, 'env to': 298, 'E-value': 1.6e-07, 'score': 42.1, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 316, 'ali to flip': 789}
# {'target name': 'NODE_10472_length_2081_cov_28.406219_bin.12', 'accession': '-', 'query name': 'IS1000B', 'accession1': '-', 'hmm len': 317, 'hmm from': 155, 'hmm to': 305, 'seq len': 2081, 'ali from': 792, 'ali to': 316, 'env from': 855, 'env to': 298, 'E-value': 2.8e-07, 'score': 42.3, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 316, 'ali to flip': 792}
# Begining Comparison:  0
# Comparing:
# Hit A: {'target name': 'NODE_10472_length_2081_cov_28.406219_bin.12', 'accession': '-', 'query name': 'IS1000A', 'accession1': '-', 'hmm len': 317, 'hmm from': 156, 'hmm to': 305, 'seq len': 2081, 'ali from': 789, 'ali to': 316, 'env from': 843, 'env to': 298, 'E-value': 1.6e-07, 'score': 42.1, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 316, 'ali to flip': 789}
# Hit B: {'target name': 'NODE_10472_length_2081_cov_28.406219_bin.12', 'accession': '-', 'query name': 'IS1000B', 'accession1': '-', 'hmm len': 317, 'hmm from': 155, 'hmm to': 305, 'seq len': 2081, 'ali from': 792, 'ali to': 316, 'env from': 855, 'env to': 298, 'E-value': 2.8e-07, 'score': 42.3, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 316, 'ali to flip': 792}
# Overlap1: 100.0%, Overlap2: 99.37106918238993%
# Choosing Hit A based on E-value
# {'target name': 'NODE_10826_length_2746_cov_4453.393906_bin.68', 'accession': '-', 'query name': 'IS1000A', 'accession1': '-', 'hmm len': 317, 'hmm from': 2, 'hmm to': 302, 'seq len': 2746, 'ali from': 1266, 'ali to': 325, 'env from': 1269, 'env to': 295, 'E-value': 1.4e-14, 'score': 65.3, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 325, 'ali to flip': 1266}
# {'target name': 'NODE_10826_length_2746_cov_4453.393906_bin.68', 'accession': '-', 'query name': 'IS1000A', 'accession1': '-', 'hmm len': 317, 'hmm from': 3, 'hmm to': 304, 'seq len': 2746, 'ali from': 2576, 'ali to': 1611, 'env from': 2582, 'env to': 1584, 'E-value': 3e-07, 'score': 41.2, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 1611, 'ali to flip': 2576}
# Begining Comparison:  0
# Comparing:
# Hit A: {'target name': 'NODE_10826_length_2746_cov_4453.393906_bin.68', 'accession': '-', 'query name': 'IS1000A', 'accession1': '-', 'hmm len': 317, 'hmm from': 2, 'hmm to': 302, 'seq len': 2746, 'ali from': 1266, 'ali to': 325, 'env from': 1269, 'env to': 295, 'E-value': 1.4e-14, 'score': 65.3, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 325, 'ali to flip': 1266}
# Hit B: {'target name': 'NODE_10826_length_2746_cov_4453.393906_bin.68', 'accession': '-', 'query name': 'IS1000A', 'accession1': '-', 'hmm len': 317, 'hmm from': 3, 'hmm to': 304, 'seq len': 2746, 'ali from': 2576, 'ali to': 1611, 'env from': 2582, 'env to': 1584, 'E-value': 3e-07, 'score': 41.2, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 1611, 'ali to flip': 2576}
# Overlap1: 0.0%, Overlap2: 0.0%
# No significant overlap or both hits retained
# {'target name': 'NODE_1102_length_39188_cov_115.496665_bin.42', 'accession': '-', 'query name': 'IS1000B', 'accession1': '-', 'hmm len': 317, 'hmm from': 51, 'hmm to': 305, 'seq len': 39188, 'ali from': 27272, 'ali to': 26481, 'env from': 27434, 'env to': 26460, 'E-value': 9.6e-12, 'score': 56.9, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 26481, 'ali to flip': 27272}
# {'target name': 'NODE_1102_length_39188_cov_115.496665_bin.42', 'accession': '-', 'query name': 'IS1000A', 'accession1': '-', 'hmm len': 317, 'hmm from': 50, 'hmm to': 305, 'seq len': 39188, 'ali from': 27275, 'ali to': 26481, 'env from': 27434, 'env to': 26460, 'E-value': 2e-11, 'score': 54.9, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 26481, 'ali to flip': 27275}
# Begining Comparison:  0
# Comparing:
# Hit A: {'target name': 'NODE_1102_length_39188_cov_115.496665_bin.42', 'accession': '-', 'query name': 'IS1000B', 'accession1': '-', 'hmm len': 317, 'hmm from': 51, 'hmm to': 305, 'seq len': 39188, 'ali from': 27272, 'ali to': 26481, 'env from': 27434, 'env to': 26460, 'E-value': 9.6e-12, 'score': 56.9, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 26481, 'ali to flip': 27272}
# Hit B: {'target name': 'NODE_1102_length_39188_cov_115.496665_bin.42', 'accession': '-', 'query name': 'IS1000A', 'accession1': '-', 'hmm len': 317, 'hmm from': 50, 'hmm to': 305, 'seq len': 39188, 'ali from': 27275, 'ali to': 26481, 'env from': 27434, 'env to': 26460, 'E-value': 2e-11, 'score': 54.9, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 26481, 'ali to flip': 27275}
# Overlap1: 100.0%, Overlap2: 99.62264150943396%
# Choosing Hit A based on E-value
# {'target name': 'NODE_1205_length_35215_cov_6.285922_bin.18', 'accession': '-', 'query name': 'IS1000A', 'accession1': '-', 'hmm len': 317, 'hmm from': 175, 'hmm to': 304, 'seq len': 35215, 'ali from': 1041, 'ali to': 640, 'env from': 1104, 'env to': 613, 'E-value': 1.5e-09, 'score': 48.8, 'bias': 0.1, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 640, 'ali to flip': 1041}
# {'target name': 'NODE_1205_length_35215_cov_6.285922_bin.18', 'accession': '-', 'query name': 'IS1000B', 'accession1': '-', 'hmm len': 317, 'hmm from': 175, 'hmm to': 303, 'seq len': 35215, 'ali from': 1041, 'ali to': 643, 'env from': 1105, 'env to': 610, 'E-value': 5.1e-07, 'score': 45.9, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 643, 'ali to flip': 1041}
# Begining Comparison:  0
# Comparing:
# Hit A: {'target name': 'NODE_1205_length_35215_cov_6.285922_bin.18', 'accession': '-', 'query name': 'IS1000A', 'accession1': '-', 'hmm len': 317, 'hmm from': 175, 'hmm to': 304, 'seq len': 35215, 'ali from': 1041, 'ali to': 640, 'env from': 1104, 'env to': 613, 'E-value': 1.5e-09, 'score': 48.8, 'bias': 0.1, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 640, 'ali to flip': 1041}
# Hit B: {'target name': 'NODE_1205_length_35215_cov_6.285922_bin.18', 'accession': '-', 'query name': 'IS1000B', 'accession1': '-', 'hmm len': 317, 'hmm from': 175, 'hmm to': 303, 'seq len': 35215, 'ali from': 1041, 'ali to': 643, 'env from': 1105, 'env to': 610, 'E-value': 5.1e-07, 'score': 45.9, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 643, 'ali to flip': 1041}
# Overlap1: 99.25373134328358%, Overlap2: 100.0%
# Choosing Hit A based on E-value
# {'target name': 'NODE_12098_length_2940_cov_13.667591_bin.2', 'accession': '-', 'query name': 'IS1000B', 'accession1': '-', 'hmm len': 317, 'hmm from': 146, 'hmm to': 300, 'seq len': 2940, 'ali from': 1607, 'ali to': 1131, 'env from': 1664, 'env to': 1104, 'E-value': 2.8e-07, 'score': 42.2, 'bias': 0.2, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 1131, 'ali to flip': 1607}
# {'target name': 'NODE_12098_length_2940_cov_13.667591_bin.2', 'accession': '-', 'query name': 'IS1000A', 'accession1': '-', 'hmm len': 317, 'hmm from': 143, 'hmm to': 300, 'seq len': 2940, 'ali from': 1616, 'ali to': 1131, 'env from': 1670, 'env to': 1104, 'E-value': 9.4e-08, 'score': 42.9, 'bias': 0.3, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 1131, 'ali to flip': 1616}
# Begining Comparison:  0
# Comparing:
# Hit A: {'target name': 'NODE_12098_length_2940_cov_13.667591_bin.2', 'accession': '-', 'query name': 'IS1000B', 'accession1': '-', 'hmm len': 317, 'hmm from': 146, 'hmm to': 300, 'seq len': 2940, 'ali from': 1607, 'ali to': 1131, 'env from': 1664, 'env to': 1104, 'E-value': 2.8e-07, 'score': 42.2, 'bias': 0.2, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 1131, 'ali to flip': 1607}
# Hit B: {'target name': 'NODE_12098_length_2940_cov_13.667591_bin.2', 'accession': '-', 'query name': 'IS1000A', 'accession1': '-', 'hmm len': 317, 'hmm from': 143, 'hmm to': 300, 'seq len': 2940, 'ali from': 1616, 'ali to': 1131, 'env from': 1670, 'env to': 1104, 'E-value': 9.4e-08, 'score': 42.9, 'bias': 0.3, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 1131, 'ali to flip': 1616}
# Overlap1: 100.0%, Overlap2: 98.14814814814815%
# Choosing Hit B based on E-value
# {'target name': 'NODE_13541_length_2244_cov_3.652353_bin.81', 'accession': '-', 'query name': 'IS1000B', 'accession1': '-', 'hmm len': 317, 'hmm from': 51, 'hmm to': 305, 'seq len': 2244, 'ali from': 1552, 'ali to': 761, 'env from': 1714, 'env to': 740, 'E-value': 9.6e-12, 'score': 56.9, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 761, 'ali to flip': 1552}
# {'target name': 'NODE_13541_length_2244_cov_3.652353_bin.81', 'accession': '-', 'query name': 'IS1000A', 'accession1': '-', 'hmm len': 317, 'hmm from': 50, 'hmm to': 305, 'seq len': 2244, 'ali from': 1555, 'ali to': 761, 'env from': 1714, 'env to': 740, 'E-value': 2e-11, 'score': 54.9, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 761, 'ali to flip': 1555}
# Begining Comparison:  0
# Comparing:
# Hit A: {'target name': 'NODE_13541_length_2244_cov_3.652353_bin.81', 'accession': '-', 'query name': 'IS1000B', 'accession1': '-', 'hmm len': 317, 'hmm from': 51, 'hmm to': 305, 'seq len': 2244, 'ali from': 1552, 'ali to': 761, 'env from': 1714, 'env to': 740, 'E-value': 9.6e-12, 'score': 56.9, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 761, 'ali to flip': 1552}
# Hit B: {'target name': 'NODE_13541_length_2244_cov_3.652353_bin.81', 'accession': '-', 'query name': 'IS1000A', 'accession1': '-', 'hmm len': 317, 'hmm from': 50, 'hmm to': 305, 'seq len': 2244, 'ali from': 1555, 'ali to': 761, 'env from': 1714, 'env to': 740, 'E-value': 2e-11, 'score': 54.9, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 761, 'ali to flip': 1555}
# Overlap1: 100.0%, Overlap2: 99.62264150943396%
# Choosing Hit A based on E-value
# {'target name': 'NODE_14223_length_5152_cov_2.853247_bin.65', 'accession': '-', 'query name': 'IS1000A', 'accession1': '-', 'hmm len': 317, 'hmm from': 149, 'hmm to': 305, 'seq len': 5152, 'ali from': 2685, 'ali to': 2215, 'env from': 2784, 'env to': 2197, 'E-value': 1.1e-07, 'score': 42.6, 'bias': 0.1, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 2215, 'ali to flip': 2685}
# {'target name': 'NODE_14223_length_5152_cov_2.853247_bin.65', 'accession': '-', 'query name': 'IS1000B', 'accession1': '-', 'hmm len': 317, 'hmm from': 142, 'hmm to': 305, 'seq len': 5152, 'ali from': 2706, 'ali to': 2215, 'env from': 2757, 'env to': 2197, 'E-value': 1.3e-07, 'score': 43.3, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 2215, 'ali to flip': 2706}
# Begining Comparison:  0
# Comparing:
# Hit A: {'target name': 'NODE_14223_length_5152_cov_2.853247_bin.65', 'accession': '-', 'query name': 'IS1000A', 'accession1': '-', 'hmm len': 317, 'hmm from': 149, 'hmm to': 305, 'seq len': 5152, 'ali from': 2685, 'ali to': 2215, 'env from': 2784, 'env to': 2197, 'E-value': 1.1e-07, 'score': 42.6, 'bias': 0.1, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 2215, 'ali to flip': 2685}
# Hit B: {'target name': 'NODE_14223_length_5152_cov_2.853247_bin.65', 'accession': '-', 'query name': 'IS1000B', 'accession1': '-', 'hmm len': 317, 'hmm from': 142, 'hmm to': 305, 'seq len': 5152, 'ali from': 2706, 'ali to': 2215, 'env from': 2757, 'env to': 2197, 'E-value': 1.3e-07, 'score': 43.3, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 2215, 'ali to flip': 2706}
# Overlap1: 100.0%, Overlap2: 95.73170731707317%
# Choosing Hit A based on E-value
# {'target name': 'NODE_1526_length_15612_cov_8.017677_bin.23', 'accession': '-', 'query name': 'D4GST8', 'accession1': '-', 'hmm len': 299, 'hmm from': 64, 'hmm to': 272, 'seq len': 15612, 'ali from': 13104, 'ali to': 12442, 'env from': 13107, 'env to': 12403, 'E-value': 1.8000000000000001e-22, 'score': 92.2, 'bias': 0.1, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 12442, 'ali to flip': 13104}
# {'target name': 'NODE_1526_length_15612_cov_8.017677_bin.23', 'accession': '-', 'query name': 'D4GST8', 'accession1': '-', 'hmm len': 299, 'hmm from': 3, 'hmm to': 169, 'seq len': 15612, 'ali from': 13314, 'ali to': 12766, 'env from': 13320, 'env to': 12766, 'E-value': 1.2e-11, 'score': 56.7, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 12766, 'ali to flip': 13314}
# Begining Comparison:  0
# Comparing:
# Hit A: {'target name': 'NODE_1526_length_15612_cov_8.017677_bin.23', 'accession': '-', 'query name': 'D4GST8', 'accession1': '-', 'hmm len': 299, 'hmm from': 64, 'hmm to': 272, 'seq len': 15612, 'ali from': 13104, 'ali to': 12442, 'env from': 13107, 'env to': 12403, 'E-value': 1.8000000000000001e-22, 'score': 92.2, 'bias': 0.1, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 12442, 'ali to flip': 13104}
# Hit B: {'target name': 'NODE_1526_length_15612_cov_8.017677_bin.23', 'accession': '-', 'query name': 'D4GST8', 'accession1': '-', 'hmm len': 299, 'hmm from': 3, 'hmm to': 169, 'seq len': 15612, 'ali from': 13314, 'ali to': 12766, 'env from': 13320, 'env to': 12766, 'E-value': 1.2e-11, 'score': 56.7, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 12766, 'ali to flip': 13314}
# Overlap1: 51.13122171945701%, Overlap2: 61.74863387978142%
# No significant overlap or both hits retained
# {'target name': 'NODE_16022_length_1328_cov_1812.373134_bin.50', 'accession': '-', 'query name': 'IS1000A', 'accession1': '-', 'hmm len': 317, 'hmm from': 175, 'hmm to': 304, 'seq len': 1328, 'ali from': 696, 'ali to': 295, 'env from': 792, 'env to': 268, 'E-value': 8.4e-09, 'score': 46.3, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 295, 'ali to flip': 696}
# {'target name': 'NODE_16022_length_1328_cov_1812.373134_bin.50', 'accession': '-', 'query name': 'IS1000B', 'accession1': '-', 'hmm len': 317, 'hmm from': 174, 'hmm to': 304, 'seq len': 1328, 'ali from': 699, 'ali to': 295, 'env from': 801, 'env to': 268, 'E-value': 1.6e-08, 'score': 46.4, 'bias': 0.1, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 295, 'ali to flip': 699}
# Begining Comparison:  0
# Comparing:
# Hit A: {'target name': 'NODE_16022_length_1328_cov_1812.373134_bin.50', 'accession': '-', 'query name': 'IS1000A', 'accession1': '-', 'hmm len': 317, 'hmm from': 175, 'hmm to': 304, 'seq len': 1328, 'ali from': 696, 'ali to': 295, 'env from': 792, 'env to': 268, 'E-value': 8.4e-09, 'score': 46.3, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 295, 'ali to flip': 696}
# Hit B: {'target name': 'NODE_16022_length_1328_cov_1812.373134_bin.50', 'accession': '-', 'query name': 'IS1000B', 'accession1': '-', 'hmm len': 317, 'hmm from': 174, 'hmm to': 304, 'seq len': 1328, 'ali from': 699, 'ali to': 295, 'env from': 801, 'env to': 268, 'E-value': 1.6e-08, 'score': 46.4, 'bias': 0.1, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 295, 'ali to flip': 699}
# Overlap1: 100.0%, Overlap2: 99.25925925925925%
# Choosing Hit A based on E-value
# {'target name': 'NODE_16976_length_5257_cov_5.285659_bin.44', 'accession': '-', 'query name': 'IS1000A', 'accession1': '-', 'hmm len': 317, 'hmm from': 179, 'hmm to': 297, 'seq len': 5257, 'ali from': 1445, 'ali to': 1071, 'env from': 1511, 'env to': 1044, 'E-value': 1e-10, 'score': 52.6, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 1071, 'ali to flip': 1445}
# {'target name': 'NODE_16976_length_5257_cov_5.285659_bin.44', 'accession': '-', 'query name': 'IS1000B', 'accession1': '-', 'hmm len': 317, 'hmm from': 178, 'hmm to': 297, 'seq len': 5257, 'ali from': 1448, 'ali to': 1071, 'env from': 1517, 'env to': 1044, 'E-value': 1.9e-10, 'score': 52.6, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 1071, 'ali to flip': 1448}
# Begining Comparison:  0
# Comparing:
# Hit A: {'target name': 'NODE_16976_length_5257_cov_5.285659_bin.44', 'accession': '-', 'query name': 'IS1000A', 'accession1': '-', 'hmm len': 317, 'hmm from': 179, 'hmm to': 297, 'seq len': 5257, 'ali from': 1445, 'ali to': 1071, 'env from': 1511, 'env to': 1044, 'E-value': 1e-10, 'score': 52.6, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 1071, 'ali to flip': 1445}
# Hit B: {'target name': 'NODE_16976_length_5257_cov_5.285659_bin.44', 'accession': '-', 'query name': 'IS1000B', 'accession1': '-', 'hmm len': 317, 'hmm from': 178, 'hmm to': 297, 'seq len': 5257, 'ali from': 1448, 'ali to': 1071, 'env from': 1517, 'env to': 1044, 'E-value': 1.9e-10, 'score': 52.6, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 1071, 'ali to flip': 1448}
# Overlap1: 100.0%, Overlap2: 99.20634920634922%
# Choosing Hit A based on E-value
# {'target name': 'NODE_1772_length_20007_cov_128.203037_bin.13', 'accession': '-', 'query name': 'IS1000A', 'accession1': '-', 'hmm len': 317, 'hmm from': 3, 'hmm to': 305, 'seq len': 20007, 'ali from': 5490, 'ali to': 4540, 'env from': 5496, 'env to': 4510, 'E-value': 3.2e-08, 'score': 44.4, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 4540, 'ali to flip': 5490}
# {'target name': 'NODE_1772_length_20007_cov_128.203037_bin.13', 'accession': '-', 'query name': 'IS1000A', 'accession1': '-', 'hmm len': 317, 'hmm from': 1, 'hmm to': 301, 'seq len': 20007, 'ali from': 6722, 'ali to': 5814, 'env from': 6729, 'env to': 5778, 'E-value': 1e-16, 'score': 76.7, 'bias': 0.0, 'shifts': 6, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 5814, 'ali to flip': 6722}
# Begining Comparison:  0
# Comparing:
# Hit A: {'target name': 'NODE_1772_length_20007_cov_128.203037_bin.13', 'accession': '-', 'query name': 'IS1000A', 'accession1': '-', 'hmm len': 317, 'hmm from': 3, 'hmm to': 305, 'seq len': 20007, 'ali from': 5490, 'ali to': 4540, 'env from': 5496, 'env to': 4510, 'E-value': 3.2e-08, 'score': 44.4, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 4540, 'ali to flip': 5490}
# Hit B: {'target name': 'NODE_1772_length_20007_cov_128.203037_bin.13', 'accession': '-', 'query name': 'IS1000A', 'accession1': '-', 'hmm len': 317, 'hmm from': 1, 'hmm to': 301, 'seq len': 20007, 'ali from': 6722, 'ali to': 5814, 'env from': 6729, 'env to': 5778, 'E-value': 1e-16, 'score': 76.7, 'bias': 0.0, 'shifts': 6, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 5814, 'ali to flip': 6722}
# Overlap1: 0.0%, Overlap2: 0.0%
# No significant overlap or both hits retained
# {'target name': 'NODE_1802_length_24189_cov_5.051918_bin.32', 'accession': '-', 'query name': 'O57809', 'accession1': '-', 'hmm len': 325, 'hmm from': 7, 'hmm to': 315, 'seq len': 24189, 'ali from': 3914, 'ali to': 2967, 'env from': 3929, 'env to': 2949, 'E-value': 1.6000000000000002e-65, 'score': 232.6, 'bias': 0.2, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 2967, 'ali to flip': 3914}
# {'target name': 'NODE_1802_length_24189_cov_5.051918_bin.32', 'accession': '-', 'query name': 'O57809', 'accession1': '-', 'hmm len': 325, 'hmm from': 5, 'hmm to': 315, 'seq len': 24189, 'ali from': 4946, 'ali to': 3975, 'env from': 4955, 'env to': 3957, 'E-value': 1.3000000000000001e-48, 'score': 177.0, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 3975, 'ali to flip': 4946}
# Begining Comparison:  0
# Comparing:
# Hit A: {'target name': 'NODE_1802_length_24189_cov_5.051918_bin.32', 'accession': '-', 'query name': 'O57809', 'accession1': '-', 'hmm len': 325, 'hmm from': 7, 'hmm to': 315, 'seq len': 24189, 'ali from': 3914, 'ali to': 2967, 'env from': 3929, 'env to': 2949, 'E-value': 1.6000000000000002e-65, 'score': 232.6, 'bias': 0.2, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 2967, 'ali to flip': 3914}
# Hit B: {'target name': 'NODE_1802_length_24189_cov_5.051918_bin.32', 'accession': '-', 'query name': 'O57809', 'accession1': '-', 'hmm len': 325, 'hmm from': 5, 'hmm to': 315, 'seq len': 24189, 'ali from': 4946, 'ali to': 3975, 'env from': 4955, 'env to': 3957, 'E-value': 1.3000000000000001e-48, 'score': 177.0, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 3975, 'ali to flip': 4946}
# Overlap1: 0.0%, Overlap2: 0.0%
# No significant overlap or both hits retained
# {'target name': 'NODE_18179_length_1139_cov_162.565498_bin.74', 'accession': '-', 'query name': 'IS1000B', 'accession1': '-', 'hmm len': 317, 'hmm from': 162, 'hmm to': 300, 'seq len': 1139, 'ali from': 602, 'ali to': 186, 'env from': 686, 'env to': 144, 'E-value': 6e-07, 'score': 41.2, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 186, 'ali to flip': 602}
# {'target name': 'NODE_18179_length_1139_cov_162.565498_bin.74', 'accession': '-', 'query name': 'IS1000A', 'accession1': '-', 'hmm len': 317, 'hmm from': 160, 'hmm to': 300, 'seq len': 1139, 'ali from': 608, 'ali to': 186, 'env from': 737, 'env to': 144, 'E-value': 1.4e-07, 'score': 42.3, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 186, 'ali to flip': 608}
# Begining Comparison:  0
# Comparing:
# Hit A: {'target name': 'NODE_18179_length_1139_cov_162.565498_bin.74', 'accession': '-', 'query name': 'IS1000B', 'accession1': '-', 'hmm len': 317, 'hmm from': 162, 'hmm to': 300, 'seq len': 1139, 'ali from': 602, 'ali to': 186, 'env from': 686, 'env to': 144, 'E-value': 6e-07, 'score': 41.2, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 186, 'ali to flip': 602}
# Hit B: {'target name': 'NODE_18179_length_1139_cov_162.565498_bin.74', 'accession': '-', 'query name': 'IS1000A', 'accession1': '-', 'hmm len': 317, 'hmm from': 160, 'hmm to': 300, 'seq len': 1139, 'ali from': 608, 'ali to': 186, 'env from': 737, 'env to': 144, 'E-value': 1.4e-07, 'score': 42.3, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 186, 'ali to flip': 608}
# Overlap1: 100.0%, Overlap2: 98.58156028368793%
# Choosing Hit B based on E-value
# {'target name': 'NODE_18587_length_4770_cov_6.887381_bin.118', 'accession': '-', 'query name': 'IS1000B', 'accession1': '-', 'hmm len': 317, 'hmm from': 75, 'hmm to': 306, 'seq len': 4770, 'ali from': 1704, 'ali to': 999, 'env from': 1728, 'env to': 979, 'E-value': 5.4e-13, 'score': 65.5, 'bias': 0.0, 'shifts': 3, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 999, 'ali to flip': 1704}
# {'target name': 'NODE_18587_length_4770_cov_6.887381_bin.118', 'accession': '-', 'query name': 'IS1000A', 'accession1': '-', 'hmm len': 317, 'hmm from': 74, 'hmm to': 306, 'seq len': 4770, 'ali from': 1707, 'ali to': 999, 'env from': 1752, 'env to': 978, 'E-value': 7.4e-14, 'score': 67.4, 'bias': 0.0, 'shifts': 3, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 999, 'ali to flip': 1707}
# Begining Comparison:  0
# Comparing:
# Hit A: {'target name': 'NODE_18587_length_4770_cov_6.887381_bin.118', 'accession': '-', 'query name': 'IS1000B', 'accession1': '-', 'hmm len': 317, 'hmm from': 75, 'hmm to': 306, 'seq len': 4770, 'ali from': 1704, 'ali to': 999, 'env from': 1728, 'env to': 979, 'E-value': 5.4e-13, 'score': 65.5, 'bias': 0.0, 'shifts': 3, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 999, 'ali to flip': 1704}
# Hit B: {'target name': 'NODE_18587_length_4770_cov_6.887381_bin.118', 'accession': '-', 'query name': 'IS1000A', 'accession1': '-', 'hmm len': 317, 'hmm from': 74, 'hmm to': 306, 'seq len': 4770, 'ali from': 1707, 'ali to': 999, 'env from': 1752, 'env to': 978, 'E-value': 7.4e-14, 'score': 67.4, 'bias': 0.0, 'shifts': 3, 'stops': 0, 'pipe': 'fs', 'description of target': '-', 'strand': '-', 'ali from flip': 999, 'ali to flip': 1707}
# Overlap1: 100.0%, Overlap2: 99.5768688293371%
# Choosing Hit B based on E-value
# {'target name': 'NODE_19051_length_2221_cov_4.028163_bin.107', 'accession': '-', 'query name': 'IS1000A', 'accession1': '-', 'hmm len': 317, 'hmm from': 116, 'hmm to': 299, 'seq len': 2221, 'ali from': 909, 'ali to': 355, 'env from': 948, 'env to': 334, 'E-value': 5.5e-08, 'score': 43.6, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 355, 'ali to flip': 909}
# {'target name': 'NODE_19051_length_2221_cov_4.028163_bin.107', 'accession': '-', 'query name': 'IS1000B', 'accession1': '-', 'hmm len': 317, 'hmm from': 109, 'hmm to': 299, 'seq len': 2221, 'ali from': 930, 'ali to': 355, 'env from': 957, 'env to': 334, 'E-value': 4.4e-08, 'score': 44.9, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 355, 'ali to flip': 930}
# Begining Comparison:  0
# Comparing:
# Hit A: {'target name': 'NODE_19051_length_2221_cov_4.028163_bin.107', 'accession': '-', 'query name': 'IS1000A', 'accession1': '-', 'hmm len': 317, 'hmm from': 116, 'hmm to': 299, 'seq len': 2221, 'ali from': 909, 'ali to': 355, 'env from': 948, 'env to': 334, 'E-value': 5.5e-08, 'score': 43.6, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 355, 'ali to flip': 909}
# Hit B: {'target name': 'NODE_19051_length_2221_cov_4.028163_bin.107', 'accession': '-', 'query name': 'IS1000B', 'accession1': '-', 'hmm len': 317, 'hmm from': 109, 'hmm to': 299, 'seq len': 2221, 'ali from': 930, 'ali to': 355, 'env from': 957, 'env to': 334, 'E-value': 4.4e-08, 'score': 44.9, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 355, 'ali to flip': 930}
# Overlap1: 100.0%, Overlap2: 96.35416666666666%
# Choosing Hit B based on E-value
# {'target name': 'NODE_198_length_99961_cov_26.077062_bin.67', 'accession': '-', 'query name': 'IS1000B', 'accession1': '-', 'hmm len': 317, 'hmm from': 146, 'hmm to': 300, 'seq len': 99961, 'ali from': 97541, 'ali to': 97065, 'env from': 97598, 'env to': 97038, 'E-value': 2.8e-07, 'score': 42.2, 'bias': 0.2, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 97065, 'ali to flip': 97541}
# {'target name': 'NODE_198_length_99961_cov_26.077062_bin.67', 'accession': '-', 'query name': 'IS1000A', 'accession1': '-', 'hmm len': 317, 'hmm from': 143, 'hmm to': 300, 'seq len': 99961, 'ali from': 97550, 'ali to': 97065, 'env from': 97604, 'env to': 97038, 'E-value': 9.4e-08, 'score': 42.9, 'bias': 0.3, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 97065, 'ali to flip': 97550}
# Begining Comparison:  0
# Comparing:
# Hit A: {'target name': 'NODE_198_length_99961_cov_26.077062_bin.67', 'accession': '-', 'query name': 'IS1000B', 'accession1': '-', 'hmm len': 317, 'hmm from': 146, 'hmm to': 300, 'seq len': 99961, 'ali from': 97541, 'ali to': 97065, 'env from': 97598, 'env to': 97038, 'E-value': 2.8e-07, 'score': 42.2, 'bias': 0.2, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 97065, 'ali to flip': 97541}
# Hit B: {'target name': 'NODE_198_length_99961_cov_26.077062_bin.67', 'accession': '-', 'query name': 'IS1000A', 'accession1': '-', 'hmm len': 317, 'hmm from': 143, 'hmm to': 300, 'seq len': 99961, 'ali from': 97550, 'ali to': 97065, 'env from': 97604, 'env to': 97038, 'E-value': 9.4e-08, 'score': 42.9, 'bias': 0.3, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 97065, 'ali to flip': 97550}
# Overlap1: 100.0%, Overlap2: 98.14814814814815%
# Choosing Hit B based on E-value
# {'target name': 'NODE_20207_length_2741_cov_4.539464_bin.76', 'accession': '-', 'query name': 'IS1000A', 'accession1': '-', 'hmm len': 317, 'hmm from': 3, 'hmm to': 305, 'seq len': 2741, 'ali from': 1918, 'ali to': 968, 'env from': 1924, 'env to': 938, 'E-value': 8.2e-08, 'score': 43.1, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 968, 'ali to flip': 1918}
# {'target name': 'NODE_20207_length_2741_cov_4.539464_bin.76', 'accession': '-', 'query name': 'IS1000A', 'accession1': '-', 'hmm len': 317, 'hmm from': 191, 'hmm to': 301, 'seq len': 2741, 'ali from': 2580, 'ali to': 2242, 'env from': 2589, 'env to': 2218, 'E-value': 1e-09, 'score': 49.3, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 2242, 'ali to flip': 2580}
# Begining Comparison:  0
# Comparing:
# Hit A: {'target name': 'NODE_20207_length_2741_cov_4.539464_bin.76', 'accession': '-', 'query name': 'IS1000A', 'accession1': '-', 'hmm len': 317, 'hmm from': 3, 'hmm to': 305, 'seq len': 2741, 'ali from': 1918, 'ali to': 968, 'env from': 1924, 'env to': 938, 'E-value': 8.2e-08, 'score': 43.1, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 968, 'ali to flip': 1918}
# Hit B: {'target name': 'NODE_20207_length_2741_cov_4.539464_bin.76', 'accession': '-', 'query name': 'IS1000A', 'accession1': '-', 'hmm len': 317, 'hmm from': 191, 'hmm to': 301, 'seq len': 2741, 'ali from': 2580, 'ali to': 2242, 'env from': 2589, 'env to': 2218, 'E-value': 1e-09, 'score': 49.3, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 2242, 'ali to flip': 2580}
# Overlap1: 0.0%, Overlap2: 0.0%
# No significant overlap or both hits retained
# {'target name': 'NODE_209_length_89412_cov_10.005920_bin.60', 'accession': '-', 'query name': 'IS1000A', 'accession1': '-', 'hmm len': 317, 'hmm from': 4, 'hmm to': 306, 'seq len': 89412, 'ali from': 4715, 'ali to': 3813, 'env from': 4721, 'env to': 3792, 'E-value': 1.4e-27, 'score': 107.9, 'bias': 0.4, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 3813, 'ali to flip': 4715}
# {'target name': 'NODE_209_length_89412_cov_10.005920_bin.60', 'accession': '-', 'query name': 'IS1000A', 'accession1': '-', 'hmm len': 317, 'hmm from': 4, 'hmm to': 305, 'seq len': 89412, 'ali from': 59818, 'ali to': 58883, 'env from': 59827, 'env to': 58853, 'E-value': 4.8e-28, 'score': 109.5, 'bias': 0.1, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 58883, 'ali to flip': 59818}
# Begining Comparison:  0
# Comparing:
# Hit A: {'target name': 'NODE_209_length_89412_cov_10.005920_bin.60', 'accession': '-', 'query name': 'IS1000A', 'accession1': '-', 'hmm len': 317, 'hmm from': 4, 'hmm to': 306, 'seq len': 89412, 'ali from': 4715, 'ali to': 3813, 'env from': 4721, 'env to': 3792, 'E-value': 1.4e-27, 'score': 107.9, 'bias': 0.4, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 3813, 'ali to flip': 4715}
# Hit B: {'target name': 'NODE_209_length_89412_cov_10.005920_bin.60', 'accession': '-', 'query name': 'IS1000A', 'accession1': '-', 'hmm len': 317, 'hmm from': 4, 'hmm to': 305, 'seq len': 89412, 'ali from': 59818, 'ali to': 58883, 'env from': 59827, 'env to': 58853, 'E-value': 4.8e-28, 'score': 109.5, 'bias': 0.1, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 58883, 'ali to flip': 59818}
# Overlap1: 0.0%, Overlap2: 0.0%
# No significant overlap or both hits retained
# {'target name': 'NODE_21744_length_1429_cov_23.879185_bin.81', 'accession': '-', 'query name': 'IS1000B', 'accession1': '-', 'hmm len': 317, 'hmm from': 194, 'hmm to': 295, 'seq len': 1429, 'ali from': 408, 'ali to': 106, 'env from': 564, 'env to': 52, 'E-value': 1.5e-07, 'score': 43.2, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 106, 'ali to flip': 408}
# {'target name': 'NODE_21744_length_1429_cov_23.879185_bin.81', 'accession': '-', 'query name': 'IS1000A', 'accession1': '-', 'hmm len': 317, 'hmm from': 193, 'hmm to': 295, 'seq len': 1429, 'ali from': 411, 'ali to': 106, 'env from': 606, 'env to': 52, 'E-value': 6.7e-08, 'score': 43.4, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 106, 'ali to flip': 411}
# Begining Comparison:  0
# Comparing:
# Hit A: {'target name': 'NODE_21744_length_1429_cov_23.879185_bin.81', 'accession': '-', 'query name': 'IS1000B', 'accession1': '-', 'hmm len': 317, 'hmm from': 194, 'hmm to': 295, 'seq len': 1429, 'ali from': 408, 'ali to': 106, 'env from': 564, 'env to': 52, 'E-value': 1.5e-07, 'score': 43.2, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 106, 'ali to flip': 408}
# Hit B: {'target name': 'NODE_21744_length_1429_cov_23.879185_bin.81', 'accession': '-', 'query name': 'IS1000A', 'accession1': '-', 'hmm len': 317, 'hmm from': 193, 'hmm to': 295, 'seq len': 1429, 'ali from': 411, 'ali to': 106, 'env from': 606, 'env to': 52, 'E-value': 6.7e-08, 'score': 43.4, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 106, 'ali to flip': 411}
# Overlap1: 100.0%, Overlap2: 99.01960784313727%
# Choosing Hit B based on E-value
# {'target name': 'NODE_2233_length_5266_cov_4.305699_bin.52', 'accession': '-', 'query name': 'IS1000A', 'accession1': '-', 'hmm len': 317, 'hmm from': 3, 'hmm to': 131, 'seq len': 5266, 'ali from': 5022, 'ali to': 4627, 'env from': 5028, 'env to': 4555, 'E-value': 6.5e-08, 'score': 43.4, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 4627, 'ali to flip': 5022}
# {'target name': 'NODE_2233_length_5266_cov_4.305699_bin.52', 'accession': '-', 'query name': 'IS1000B', 'accession1': '-', 'hmm len': 317, 'hmm from': 3, 'hmm to': 130, 'seq len': 5266, 'ali from': 5022, 'ali to': 4630, 'env from': 5028, 'env to': 4552, 'E-value': 6.6e-07, 'score': 41.0, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 4630, 'ali to flip': 5022}
# Begining Comparison:  0
# Comparing:
# Hit A: {'target name': 'NODE_2233_length_5266_cov_4.305699_bin.52', 'accession': '-', 'query name': 'IS1000A', 'accession1': '-', 'hmm len': 317, 'hmm from': 3, 'hmm to': 131, 'seq len': 5266, 'ali from': 5022, 'ali to': 4627, 'env from': 5028, 'env to': 4555, 'E-value': 6.5e-08, 'score': 43.4, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 4627, 'ali to flip': 5022}
# Hit B: {'target name': 'NODE_2233_length_5266_cov_4.305699_bin.52', 'accession': '-', 'query name': 'IS1000B', 'accession1': '-', 'hmm len': 317, 'hmm from': 3, 'hmm to': 130, 'seq len': 5266, 'ali from': 5022, 'ali to': 4630, 'env from': 5028, 'env to': 4552, 'E-value': 6.6e-07, 'score': 41.0, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 4630, 'ali to flip': 5022}
# Overlap1: 99.24242424242425%, Overlap2: 100.0%
# Choosing Hit A based on E-value
# {'target name': 'NODE_22405_length_2036_cov_428.826350_bin.81', 'accession': '-', 'query name': 'IS1000B', 'accession1': '-', 'hmm len': 317, 'hmm from': 4, 'hmm to': 304, 'seq len': 2036, 'ali from': 1879, 'ali to': 917, 'env from': 1888, 'env to': 890, 'E-value': 9e-08, 'score': 43.9, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 917, 'ali to flip': 1879}
# {'target name': 'NODE_22405_length_2036_cov_428.826350_bin.81', 'accession': '-', 'query name': 'IS1000A', 'accession1': '-', 'hmm len': 317, 'hmm from': 3, 'hmm to': 304, 'seq len': 2036, 'ali from': 1882, 'ali to': 917, 'env from': 1888, 'env to': 890, 'E-value': 3.8e-08, 'score': 44.2, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 917, 'ali to flip': 1882}
# Begining Comparison:  0
# Comparing:
# Hit A: {'target name': 'NODE_22405_length_2036_cov_428.826350_bin.81', 'accession': '-', 'query name': 'IS1000B', 'accession1': '-', 'hmm len': 317, 'hmm from': 4, 'hmm to': 304, 'seq len': 2036, 'ali from': 1879, 'ali to': 917, 'env from': 1888, 'env to': 890, 'E-value': 9e-08, 'score': 43.9, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 917, 'ali to flip': 1879}
# Hit B: {'target name': 'NODE_22405_length_2036_cov_428.826350_bin.81', 'accession': '-', 'query name': 'IS1000A', 'accession1': '-', 'hmm len': 317, 'hmm from': 3, 'hmm to': 304, 'seq len': 2036, 'ali from': 1882, 'ali to': 917, 'env from': 1888, 'env to': 890, 'E-value': 3.8e-08, 'score': 44.2, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 917, 'ali to flip': 1882}
# Overlap1: 100.0%, Overlap2: 99.68944099378882%
# Choosing Hit B based on E-value
# {'target name': 'NODE_22818_length_1152_cov_2.111212_bin.11', 'accession': '-', 'query name': 'IS1000B', 'accession1': '-', 'hmm len': 317, 'hmm from': 31, 'hmm to': 251, 'seq len': 1152, 'ali from': 696, 'ali to': 22, 'env from': 801, 'env to': 1, 'E-value': 3e-08, 'score': 45.4, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 22, 'ali to flip': 696}
# {'target name': 'NODE_22818_length_1152_cov_2.111212_bin.11', 'accession': '-', 'query name': 'IS1000A', 'accession1': '-', 'hmm len': 317, 'hmm from': 30, 'hmm to': 251, 'seq len': 1152, 'ali from': 699, 'ali to': 22, 'env from': 801, 'env to': 1, 'E-value': 3.6e-09, 'score': 47.5, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 22, 'ali to flip': 699}
# Begining Comparison:  0
# Comparing:
# Hit A: {'target name': 'NODE_22818_length_1152_cov_2.111212_bin.11', 'accession': '-', 'query name': 'IS1000B', 'accession1': '-', 'hmm len': 317, 'hmm from': 31, 'hmm to': 251, 'seq len': 1152, 'ali from': 696, 'ali to': 22, 'env from': 801, 'env to': 1, 'E-value': 3e-08, 'score': 45.4, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 22, 'ali to flip': 696}
# Hit B: {'target name': 'NODE_22818_length_1152_cov_2.111212_bin.11', 'accession': '-', 'query name': 'IS1000A', 'accession1': '-', 'hmm len': 317, 'hmm from': 30, 'hmm to': 251, 'seq len': 1152, 'ali from': 699, 'ali to': 22, 'env from': 801, 'env to': 1, 'E-value': 3.6e-09, 'score': 47.5, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 22, 'ali to flip': 699}
# Overlap1: 100.0%, Overlap2: 99.5575221238938%
# Choosing Hit B based on E-value
# {'target name': 'NODE_25967_length_1628_cov_27.983471_bin.44', 'accession': '-', 'query name': 'IS1000A', 'accession1': '-', 'hmm len': 317, 'hmm from': 116, 'hmm to': 299, 'seq len': 1628, 'ali from': 778, 'ali to': 224, 'env from': 817, 'env to': 203, 'E-value': 5.5e-08, 'score': 43.6, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 224, 'ali to flip': 778}
# {'target name': 'NODE_25967_length_1628_cov_27.983471_bin.44', 'accession': '-', 'query name': 'IS1000B', 'accession1': '-', 'hmm len': 317, 'hmm from': 109, 'hmm to': 299, 'seq len': 1628, 'ali from': 799, 'ali to': 224, 'env from': 826, 'env to': 203, 'E-value': 4.4e-08, 'score': 44.9, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 224, 'ali to flip': 799}
# Begining Comparison:  0
# Comparing:
# Hit A: {'target name': 'NODE_25967_length_1628_cov_27.983471_bin.44', 'accession': '-', 'query name': 'IS1000A', 'accession1': '-', 'hmm len': 317, 'hmm from': 116, 'hmm to': 299, 'seq len': 1628, 'ali from': 778, 'ali to': 224, 'env from': 817, 'env to': 203, 'E-value': 5.5e-08, 'score': 43.6, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 224, 'ali to flip': 778}
# Hit B: {'target name': 'NODE_25967_length_1628_cov_27.983471_bin.44', 'accession': '-', 'query name': 'IS1000B', 'accession1': '-', 'hmm len': 317, 'hmm from': 109, 'hmm to': 299, 'seq len': 1628, 'ali from': 799, 'ali to': 224, 'env from': 826, 'env to': 203, 'E-value': 4.4e-08, 'score': 44.9, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 224, 'ali to flip': 799}
# Overlap1: 100.0%, Overlap2: 96.35416666666666%
# Choosing Hit B based on E-value
# {'target name': 'NODE_26695_length_1734_cov_3.415128_bin.68', 'accession': '-', 'query name': 'IS1000B', 'accession1': '-', 'hmm len': 317, 'hmm from': 161, 'hmm to': 305, 'seq len': 1734, 'ali from': 726, 'ali to': 268, 'env from': 774, 'env to': 241, 'E-value': 8.1e-07, 'score': 40.7, 'bias': 0.0, 'shifts': 0, 'stops': 0, 'pipe': 'std', 'description of target': '-', 'strand': '-', 'ali from flip': 268, 'ali to flip': 726}
# ...
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Length of group less than 1.
# Less than 70% deduplication done.
#                                        target name accession query name  \
# 0      NODE_10031_length_4520_cov_21.454199_bin.26         -    IS1000A
# 1      NODE_1003_length_40871_cov_15.858952_bin.35         -     D4GST8
# 2       NODE_10102_length_2253_cov_2.649227_bin.40         -     O57809
# 3      NODE_10109_length_3055_cov_21.397000_bin.41         -     D4GST8
# 4    NODE_10142_length_2697_cov_1924.647994_bin.50         -    IS1000A
# ..                                             ...       ...        ...
# 894     NODE_987_length_40971_cov_46.755401_bin.85         -     D4GST8
# 895      NODE_9970_length_3095_cov_4.721382_bin.90         -    IS1000A
# 896      NODE_9973_length_3636_cov_4.116169_bin.55         -     D4GST8
# 897       NODE_9995_length_2187_cov_3.098030_bin.7         -     D4GST8
# 898      NODE_9_length_386947_cov_84.790368_bin.28         -     D4GST8
#
#     accession1  hmm len  hmm from  hmm to  seq len  ali from  ali to  \
# 0            -      317       160     295     4520      1090    1488
# 1            -      299         2     175    40871     27424   27948
# 2            -      325       242     316     2253        23     265
# 3            -      299        50     275     3055      1659    2372
# 4            -      317         2     302     2697      1465    2406
# ..         ...      ...       ...     ...      ...       ...     ...
# 894          -      299         3     271    40971      8374    9246
# 895          -      317       156     305     3095      1355    1828
# 896          -      299         3     275     3636       850    1719
# 897          -      299         1     191     2187       696    1259
# 898          -      299         3     271   386947    185276  186148
#
#      env from  env to       E-value  score  bias  shifts  stops pipe  \
# 0        1030    1542  1.800000e-07   41.9   0.0       0      0  std
# 1       27421   28068  5.800000e-07   41.3   0.0       0      0  std
# 2           5     289  2.200000e-08   44.8   0.2       0      0  std
# 3        1482    2408  3.700000e-31  120.7   0.2       0      0  std
# 4        1462    2436  3.300000e-15   67.4   0.0       0      0  std
# ..        ...     ...           ...    ...   ...     ...    ...  ...
# 894      8368    9294  1.100000e-34  132.3   0.3       0      0  std
# 895      1283    1846  2.700000e-07   41.4   0.0       0      0  std
# 896       844    1785  2.800000e-37  140.8   1.1       0      0  std
# 897       696    1322  7.900000e-09   47.4   0.0       0      0  std
# 898    185270  186208  1.800000e-32  125.0   0.3       0      0  std
#
#     description of target strand
# 0                       -      +
# 1                       -      +
# 2                       -      +
# 3                       -      +
# 4                       -      +
# ..                    ...    ...
# 894                     -      +
# 895                     -      +
# 896                     -      +
# 897                     -      +
# 898                     -      +
#
# [899 rows x 20 columns]

# %%
complete_bath_deduplication.shape
# Out:
# (1815, 22)

# %%
complete_bath_deduplication.to_excel(deduplication_op_path)

# %%
stats = overlap_deduplications.get_statistics()
print(stats)

# %% [markdown]
# ### Single File Test

# %%
bathout = pd.read_table('/content/test_case.tbl', sep="\s+",skiprows =1, header=None)
bathout
# Define column names
col_names = ['target name', 'accession', 'query name', 'accession1', 'hmm len', 'hmm from', 'hmm to',
              'seq len', 'ali from', 'ali to', 'env from', 'env to', 'E-value', 'score', 'bias',
              'shifts', 'stops', 'pipe', 'description of target', 'extra']

# Rename columns
bathout.rename(columns=dict(zip(bathout.columns, col_names)), inplace=True)

# Process negative strand
#df_neg = filtering_operations.get_specific_strand(bathout, "-")
#neg_deduped = overlap_deduplications.choose_strand_operations(df_neg)

# Process positive strand
df_pos = filtering_operations.get_specific_strand(bathout, "+")
pos_deduped = overlap_deduplications.choose_strand_operations(df_pos)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-17393f11b864> in <cell line: 1>()
# ----> 1 bathout = pd.read_table('/content/test_case.tbl', sep="\s+",skiprows =1, header=None)
#       2 bathout
#       3 # Define column names
#       4 col_names = ['target name', 'accession', 'query name', 'accession1', 'hmm len', 'hmm from', 'hmm to',
#       5               'seq len', 'ali from', 'ali to', 'env from', 'env to', 'E-value', 'score', 'bias',
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_table(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1280     kwds.update(kwds_defaults)
#    1281
# -> 1282     return _read(filepath_or_buffer, kwds)
#    1283
#    1284
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     609
#     610     # Create the parser.
# --> 611     parser = TextFileReader(filepath_or_buffer, **kwds)
#     612
#     613     if chunksize or iterator:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1446
#    1447         self.handles: IOHandles | None = None
# -> 1448         self._engine = self._make_engine(f, self.engine)
#    1449
#    1450     def close(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1703                 if "b" not in mode:
#    1704                     mode += "b"
# -> 1705             self.handles = get_handle(
#    1706                 f,
#    1707                 mode,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     861         if ioargs.encoding and "b" not in ioargs.mode:
#     862             # Encoding
# --> 863             handle = open(
#     864                 handle,
#     865                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/test_case.tbl'

# %%
pos_deduped
